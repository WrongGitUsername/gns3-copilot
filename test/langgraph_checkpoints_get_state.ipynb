# %%
# langgraph checkpoint StateSnapshot.values

data = {
    'llm_calls': 13,
    'messages': [
        HumanMessage(
             content='Create a topology. Use 6 routers, fully interconnected, and configure the interface addresses using the 10.0.0.0/8 address range.', 
             additional_kwargs={}, 
             response_metadata={}
             ),
        AIMessage(
            content="I'll help you create a fully interconnected topology with 6 routers. Let me start by checking the available templates and current topology.", 
            additional_kwargs={'refusal': None}, 
            response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 2584, 'total_tokens': 2628, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 2560}, 'prompt_cache_hit_tokens': 2560, 'prompt_cache_miss_tokens': 24}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '54ef1c2b-6c94-4893-93b3-8118ab84a71f', 'finish_reason': 'tool_calls', 'logprobs': None}, 
            id='lc_run--50a71499-1f0f-40cf-945e-3fe18548da92-0', 
            tool_calls=[{'name': 'get_gns3_templates', 'args': {'tool_input': ''}, 'id': 'call_00_0vuwh5uJM1H569NQoM5NDQLM', 'type': 'tool_call'}], 
            usage_metadata={'input_tokens': 2584, 'output_tokens': 44, 'total_tokens': 2628, 'input_token_details': {'cache_read': 2560}, 'output_token_details': {}}
            ),
        ToolMessage(
            content="{'templates': [{'name': 'Cisco CSR1000v 17.3.8a', 'template_id': 'bed0539f-6a7e-42ed-94cd-9f46ea1ba2d0', 'template_type': 'qemu'}, {'name': 'NXOS_9500v', 'template_id': 'dbe332ac-c130-458b-b4a1-b754c09a917e', 'template_type': 'qemu'}, {'name': 'c7200', 'template_id': '7a5be161-fdbc-4577-8c7b-20da6451bae7', 'template_type': 'dynamips'}, {'name': 'IOU_L2', 'template_id': '3a66e68c-ac98-4230-8888-7a411e2798ca', 'template_type': 'iou'}, {'name': 'IOU_L3', 'template_id': '684610fa-3fb3-453a-8099-0ebac9372102', 'template_type': 'iou'}, {'name': 'IOSvL2', 'template_id': '6050bbaa-d83f-47a9-9a30-458374b84aff', 'template_type': 'qemu'}, {'name': 'nxosv9300-93.x', 'template_id': 'cd45b1bb-04bd-4919-9765-7ee9fd08c30f', 'template_type': 'qemu'}, {'name': 'Ubuntu22.04', 'template_id': '8088e57f-056f-4114-a180-0c63a6aef880', 'template_type': 'qemu'}, {'name': 'IOSv', 'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7', 'template_type': 'qemu'}, {'name': 'gns3-lab', 'template_id': '702b79fe-15bd-43ec-ae6c-cb8cf39a9965', 'template_type': 'cloud'}, {'name': 'Debian12', 'template_id': '00fec130-463f-476e-8d4c-bf19fb7a420a', 'template_type': 'qemu'}, {'name': 'Cisco CSR1000v 16.12.3', 'template_id': '43d064d0-4ebf-4394-87ba-b8c06aa516df', 'template_type': 'qemu'}, {'name': 'nxosv9300-104.3F', 'template_id': '76317608-bfe0-426a-8f21-beb274d1c61a', 'template_type': 'qemu'}, {'name': 'Cloud', 'template_id': '39e257dc-8412-3174-b6b3-0ee3ed6a43e9', 'template_type': 'cloud'}, {'name': 'NAT', 'template_id': 'df8f4ea9-33b7-3e96-86a2-c39bc9bb649c', 'template_type': 'nat'}, {'name': 'VPCS', 'template_id': '19021f99-e36f-394d-b4a1-8aaa902ab9cc', 'template_type': 'vpcs'}, {'name': 'Ethernet switch', 'template_id': '1966b864-93e7-32d5-965f-001384eec461', 'template_type': 'ethernet_switch'}, {'name': 'Ethernet hub', 'template_id': 'b4503ea9-d6b6-3695-9fe4-1db3b39290b0', 'template_type': 'ethernet_hub'}, {'name': 'Frame Relay switch', 'template_id': 'dd0f6f3a-ba58-3249-81cb-a1dd88407a47', 'template_type': 'frame_relay_switch'}, {'name': 'ATM switch', 'template_id': 'aaa764e2-b383-300f-8a0e-3493bbfdb7d2', 'template_type': 'atm_switch'}]}", 
            tool_call_id='call_00_0vuwh5uJM1H569NQoM5NDQLM'
            ),
        AIMessage(
            content="Now let me check if there's an existing project:", 
            additional_kwargs={'refusal': None}, 
            response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 3589, 'total_tokens': 3618, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 3584}, 'prompt_cache_hit_tokens': 3584, 'prompt_cache_miss_tokens': 5}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '4ad77f80-ca0c-4fb0-b953-f5c56a8d412a', 'finish_reason': 'tool_calls', 'logprobs': None}, 
            id='lc_run--24ad97ba-48fe-464d-94f8-8b5e3cae97cc-0', 
            tool_calls=[{'name': 'gns3_topology_reader', 'args': {'tool_input': None}, 'id': 'call_00_iqSSMygME10UhKWGSRRCnIko', 'type': 'tool_call'}], 
            usage_metadata={'input_tokens': 3589, 'output_tokens': 29, 'total_tokens': 3618, 'input_token_details': {'cache_read': 3584}, 'output_token_details': {}}
            ),
        ToolMessage(
            content="{'project_id': '365dd3ff-cda9-447a-94da-3a6cef75fe77', 'name': 'test', 'status': 'opened', 'nodes': {}, 'links': []}", 
            tool_call_id='call_00_iqSSMygME10UhKWGSRRCnIko'
            ),
        AIMessage(
            content="Great! I have an existing project. Now I'll create 6 routers using the IOSv template. I'll arrange them in a circular pattern for better visualization:", 
            additional_kwargs={'refusal': None}, 
            response_metadata={'token_usage': {'completion_tokens': 342, 'prompt_tokens': 3671, 'total_tokens': 4013, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 3648}, 'prompt_cache_hit_tokens': 3648, 'prompt_cache_miss_tokens': 23}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '60cdcd00-2feb-45a5-8242-7e0b2045aa67', 'finish_reason': 'tool_calls', 'logprobs': None}, 
            id='lc_run--268ea363-722b-425a-98b1-c2e542b8b930-0', 
            tool_calls=[{'name': 'create_gns3_node', 'args': {'tool_input': '{"project_id": "365dd3ff-cda9-447a-94da-3a6cef75fe77", "nodes": [{"template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7", "x": 0, "y": -300}, {"template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7", "x": 260, "y": -150}, {"template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7", "x": 260, "y": 150}, {"template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7", "x": 0, "y": 300}, {"template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7", "x": -260, "y": 150}, {"template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7", "x": -260, "y": -150}]}'}, 'id': 'call_00_s3rHITboKzq2VdpU4Wkhs2GP', 'type': 'tool_call'}], 
            usage_metadata={'input_tokens': 3671, 'output_tokens': 342, 'total_tokens': 4013, 'input_token_details': {'cache_read': 3648}, 'output_token_details': {}}
            ),

        ".........."

        AIMessage(
            content='Perfect! Let me also test connectivity between some routers to verify the fully interconnected topology is working:', 
            additional_kwargs={'refusal': None}, 
            response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 25375, 'total_tokens': 25533, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 22528}, 'prompt_cache_hit_tokens': 22528, 'prompt_cache_miss_tokens': 2847}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': 'b4cb312a-0113-479b-9449-85ab7add75ac', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--5f3dfbd9-60f5-4c7a-a011-10eb38b31ae5-0', tool_calls=[{'name': 'execute_multiple_device_commands', 'args': {'tool_input': '[\n  {\n    "device_name": "R-1",\n    "commands": ["ping 10.1.2.2", "ping 10.1.3.2", "ping 10.1.4.2"]\n  },\n  {\n    "device_name": "R-2", \n    "commands": ["ping 10.1.2.1", "ping 10.2.3.2", "ping 10.2.4.2"]\n  }\n]'}, 'id': 'call_00_Kq7UzEQsxlMsstoMQbLTTdNs', 'type': 'tool_call'}], usage_metadata={'input_tokens': 25375, 'output_tokens': 158, 'total_tokens': 25533, 'input_token_details': {'cache_read': 22528}, 'output_token_details': {}}
            )
    ]
 }
