# %%
llm_calls_1 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="I'll help you create a topology with four Cisco routers in GNS3. Let me first check what templates are available and then create the topology.",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 48,
                        "prompt_tokens": 2599,
                        "total_tokens": 2647,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 2560,
                        },
                        "prompt_cache_hit_tokens": 2560,
                        "prompt_cache_miss_tokens": 39,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "9d07f4d4-de1b-4de2-bb9d-e9c96b0e921d",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--5c5f3093-db7d-473b-a204-9fb1050c14c1-0",
                tool_calls=[
                    {
                        "name": "get_gns3_templates",
                        "args": {"tool_input": ""},
                        "id": "call_00_Ygc7XwC21vj5nY8nD9f82s8h",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 2599,
                    "output_tokens": 48,
                    "total_tokens": 2647,
                    "input_token_details": {"cache_read": 2560},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 1,
    }
}

# %%
tool_node_1 = {
    "tool_node": {
        "messages": [
            ToolMessage(
                content="{'templates': [{'name': 'Cisco CSR1000v 17.3.8a', 'template_id': 'bed0539f-6a7e-42ed-94cd-9f46ea1ba2d0', 'template_type': 'qemu'}, {'name': 'NXOS_9500v', 'template_id': 'dbe332ac-c130-458b-b4a1-b754c09a917e', 'template_type': 'qemu'}, {'name': 'c7200', 'template_id': '7a5be161-fdbc-4577-8c7b-20da6451bae7', 'template_type': 'dynamips'}, {'name': 'IOU_L2', 'template_id': '3a66e68c-ac98-4230-8888-7a411e2798ca', 'template_type': 'iou'}, {'name': 'IOU_L3', 'template_id': '684610fa-3fb3-453a-8099-0ebac9372102', 'template_type': 'iou'}, {'name': 'IOSvL2', 'template_id': '6050bbaa-d83f-47a9-9a30-458374b84aff', 'template_type': 'qemu'}, {'name': 'nxosv9300-93.x', 'template_id': 'cd45b1bb-04bd-4919-9765-7ee9fd08c30f', 'template_type': 'qemu'}, {'name': 'Ubuntu22.04', 'template_id': '8088e57f-056f-4114-a180-0c63a6aef880', 'template_type': 'qemu'}, {'name': 'IOSv', 'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7', 'template_type': 'qemu'}, {'name': 'gns3-lab', 'template_id': '702b79fe-15bd-43ec-ae6c-cb8cf39a9965', 'template_type': 'cloud'}, {'name': 'Debian12', 'template_id': '00fec130-463f-476e-8d4c-bf19fb7a420a', 'template_type': 'qemu'}, {'name': 'Cisco CSR1000v 16.12.3', 'template_id': '43d064d0-4ebf-4394-87ba-b8c06aa516df', 'template_type': 'qemu'}, {'name': 'nxosv9300-104.3F', 'template_id': '76317608-bfe0-426a-8f21-beb274d1c61a', 'template_type': 'qemu'}, {'name': 'Cloud', 'template_id': '39e257dc-8412-3174-b6b3-0ee3ed6a43e9', 'template_type': 'cloud'}, {'name': 'NAT', 'template_id': 'df8f4ea9-33b7-3e96-86a2-c39bc9bb649c', 'template_type': 'nat'}, {'name': 'VPCS', 'template_id': '19021f99-e36f-394d-b4a1-8aaa902ab9cc', 'template_type': 'vpcs'}, {'name': 'Ethernet switch', 'template_id': '1966b864-93e7-32d5-965f-001384eec461', 'template_type': 'ethernet_switch'}, {'name': 'Ethernet hub', 'template_id': 'b4503ea9-d6b6-3695-9fe4-1db3b39290b0', 'template_type': 'ethernet_hub'}, {'name': 'Frame Relay switch', 'template_id': 'dd0f6f3a-ba58-3249-81cb-a1dd88407a47', 'template_type': 'frame_relay_switch'}, {'name': 'ATM switch', 'template_id': 'aaa764e2-b383-300f-8a0e-3493bbfdb7d2', 'template_type': 'atm_switch'}]}",
                tool_call_id="call_00_Ygc7XwC21vj5nY8nD9f82s8h",
            )
        ]
    }
}

# %%
llm_calls_2 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="Now I'll create four Cisco routers using the IOSv template. I'll arrange them in a square formation:",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 281,
                        "prompt_tokens": 3608,
                        "total_tokens": 3889,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 2624,
                        },
                        "prompt_cache_hit_tokens": 2624,
                        "prompt_cache_miss_tokens": 984,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "bd0ad092-3c53-42b9-9b19-5a4d36958630",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--57ab5f7c-6ccd-42fe-86c3-353f55e5b7a5-0",
                tool_calls=[
                    {
                        "name": "create_gns3_node",
                        "args": {
                            "tool_input": '{\n  "project_id": "",\n  "nodes": [\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": -200,\n      "y": -200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": 200,\n      "y": -200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": -200,\n      "y": 200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": 200,\n      "y": 200\n    }\n  ]\n}'
                        },
                        "id": "call_00_Qe72bU2lGyLDPvQZEKoI7v6J",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 3608,
                    "output_tokens": 281,
                    "total_tokens": 3889,
                    "input_token_details": {"cache_read": 2624},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 2,
    }
}

# %%
tool_node_2 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="Now I'll create four Cisco routers using the IOSv template. I'll arrange them in a square formation:",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 281,
                        "prompt_tokens": 3608,
                        "total_tokens": 3889,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 2624,
                        },
                        "prompt_cache_hit_tokens": 2624,
                        "prompt_cache_miss_tokens": 984,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "bd0ad092-3c53-42b9-9b19-5a4d36958630",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--57ab5f7c-6ccd-42fe-86c3-353f55e5b7a5-0",
                tool_calls=[
                    {
                        "name": "create_gns3_node",
                        "args": {
                            "tool_input": '{\n  "project_id": "",\n  "nodes": [\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": -200,\n      "y": -200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": 200,\n      "y": -200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": -200,\n      "y": 200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": 200,\n      "y": 200\n    }\n  ]\n}'
                        },
                        "id": "call_00_Qe72bU2lGyLDPvQZEKoI7v6J",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 3608,
                    "output_tokens": 281,
                    "total_tokens": 3889,
                    "input_token_details": {"cache_read": 2624},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 2,
    }
}

# %%
llm_calls_3 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="I need to first check the current topology to get the project ID:",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 32,
                        "prompt_tokens": 3901,
                        "total_tokens": 3933,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 3840,
                        },
                        "prompt_cache_hit_tokens": 3840,
                        "prompt_cache_miss_tokens": 61,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "e05dbd79-ff62-4ca7-b82c-566b9c8c97dc",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--86c3e365-92bf-443b-a515-8b77ddb08120-0",
                tool_calls=[
                    {
                        "name": "gns3_topology_reader",
                        "args": {"tool_input": None},
                        "id": "call_00_TeAAkuGe7p7TGHHi5ao2kyNz",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 3901,
                    "output_tokens": 32,
                    "total_tokens": 3933,
                    "input_token_details": {"cache_read": 3840},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 3,
    }
}

# %%
tool_node_3 = {
    "tool_node": {
        "messages": [
            ToolMessage(
                content="{'project_id': '365dd3ff-cda9-447a-94da-3a6cef75fe77', 'name': 'test', 'status': 'opened', 'nodes': {}, 'links': []}",
                tool_call_id="call_00_TeAAkuGe7p7TGHHi5ao2kyNz",
            )
        ]
    }
}

# %%
llm_calls_4 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="Perfect! Now I'll create the four Cisco routers in the existing project:",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 296,
                        "prompt_tokens": 3986,
                        "total_tokens": 4282,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 3904,
                        },
                        "prompt_cache_hit_tokens": 3904,
                        "prompt_cache_miss_tokens": 82,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "323f02c4-3227-4b1d-a1fe-bee0c7e20162",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--47b98e8b-126f-430e-9916-bd397dd13ce5-0",
                tool_calls=[
                    {
                        "name": "create_gns3_node",
                        "args": {
                            "tool_input": '{\n  "project_id": "365dd3ff-cda9-447a-94da-3a6cef75fe77",\n  "nodes": [\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": -200,\n      "y": -200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": 200,\n      "y": -200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": -200,\n      "y": 200\n    },\n    {\n      "template_id": "b923a635-b7cc-4cb5-9a86-9357e04c02f7",\n      "x": 200,\n      "y": 200\n    }\n  ]\n}'
                        },
                        "id": "call_00_1AxRtzyeN11I6Hqut9x3XAUV",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 3986,
                    "output_tokens": 296,
                    "total_tokens": 4282,
                    "input_token_details": {"cache_read": 3904},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 4,
    }
}

# %%
tool_node_4 = {
    "tool_node": {
        "messages": [
            ToolMessage(
                content="{'project_id': '365dd3ff-cda9-447a-94da-3a6cef75fe77', 'created_nodes': [{'node_id': '6ec10265-c872-497a-8b73-1dc989c065e0', 'name': 'R-1', 'status': 'success'}, {'node_id': 'f3b9fea5-dbff-4099-8e3b-b088c32f7a45', 'name': 'R-2', 'status': 'success'}, {'node_id': 'ef782ded-ee4c-42c3-9db9-2a2fd4dc0552', 'name': 'R-3', 'status': 'success'}, {'node_id': '11069fb2-8c0b-455b-8b91-72ae92eae201', 'name': 'R-4', 'status': 'success'}], 'total_nodes': 4, 'successful_nodes': 4, 'failed_nodes': 0}",
                tool_call_id="call_00_1AxRtzyeN11I6Hqut9x3XAUV",
            )
        ]
    }
}

# %%
llm_calls_5 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="Great! I've successfully created a topology with four Cisco routers. Let me verify the topology:",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 37,
                        "prompt_tokens": 4518,
                        "total_tokens": 4555,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 4224,
                        },
                        "prompt_cache_hit_tokens": 4224,
                        "prompt_cache_miss_tokens": 294,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "268cd6ee-8abe-4a32-bdcd-91a0cbb1edc7",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--0321eb17-c381-4006-a2c8-4b76e4123bcf-0",
                tool_calls=[
                    {
                        "name": "gns3_topology_reader",
                        "args": {"tool_input": None},
                        "id": "call_00_ISqGMOuC3dmodc2N1Mywcgty",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 4518,
                    "output_tokens": 37,
                    "total_tokens": 4555,
                    "input_token_details": {"cache_read": 4224},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 5,
    }
}

# %%
tool_node_5 = {
    "tool_node": {
        "messages": [
            ToolMessage(
                content="{'project_id': '365dd3ff-cda9-447a-94da-3a6cef75fe77', 'name': 'test', 'status': 'opened', 'nodes': {'R-1': {'server': '127.0.0.1', 'name': 'R-1', 'node_id': '6ec10265-c872-497a-8b73-1dc989c065e0', 'console_port': 5000, 'console_type': 'telnet', 'type': 'qemu', 'ports': [{'adapter_number': 0, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:00', 'name': 'Ge 0/0', 'port_number': 0, 'short_name': 'Ge 0/0'}, {'adapter_number': 1, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:01', 'name': 'Ge 0/1', 'port_number': 0, 'short_name': 'Ge 0/1'}, {'adapter_number': 2, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:02', 'name': 'Ge 0/2', 'port_number': 0, 'short_name': 'Ge 0/2'}, {'adapter_number': 3, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:03', 'name': 'Ge 0/3', 'port_number': 0, 'short_name': 'Ge 0/3'}, {'adapter_number': 4, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:04', 'name': 'Ge 0/4', 'port_number': 0, 'short_name': 'Ge 0/4'}, {'adapter_number': 5, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:05', 'name': 'Ge 0/5', 'port_number': 0, 'short_name': 'Ge 0/5'}, {'adapter_number': 6, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:06', 'name': 'Ge 0/6', 'port_number': 0, 'short_name': 'Ge 0/6'}, {'adapter_number': 7, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:07', 'name': 'Ge 0/7', 'port_number': 0, 'short_name': 'Ge 0/7'}, {'adapter_number': 8, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:08', 'name': 'Ge 0/8', 'port_number': 0, 'short_name': 'Ge 0/8'}, {'adapter_number': 9, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:09', 'name': 'Ge 0/9', 'port_number': 0, 'short_name': 'Ge 0/9'}, {'adapter_number': 10, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:0a', 'name': 'Ge 0/10', 'port_number': 0, 'short_name': 'Ge 0/10'}, {'adapter_number': 11, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:0b', 'name': 'Ge 0/11', 'port_number': 0, 'short_name': 'Ge 0/11'}, {'adapter_number': 12, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:0c', 'name': 'Ge 0/12', 'port_number': 0, 'short_name': 'Ge 0/12'}, {'adapter_number': 13, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:0d', 'name': 'Ge 0/13', 'port_number': 0, 'short_name': 'Ge 0/13'}, {'adapter_number': 14, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:0e', 'name': 'Ge 0/14', 'port_number': 0, 'short_name': 'Ge 0/14'}, {'adapter_number': 15, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:c1:02:65:00:0f', 'name': 'Ge 0/15', 'port_number': 0, 'short_name': 'Ge 0/15'}], 'x': -200, 'y': -200}, 'R-2': {'server': '127.0.0.1', 'name': 'R-2', 'node_id': 'f3b9fea5-dbff-4099-8e3b-b088c32f7a45', 'console_port': 5002, 'console_type': 'telnet', 'type': 'qemu', 'ports': [{'adapter_number': 0, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:00', 'name': 'Ge 0/0', 'port_number': 0, 'short_name': 'Ge 0/0'}, {'adapter_number': 1, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:01', 'name': 'Ge 0/1', 'port_number': 0, 'short_name': 'Ge 0/1'}, {'adapter_number': 2, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:02', 'name': 'Ge 0/2', 'port_number': 0, 'short_name': 'Ge 0/2'}, {'adapter_number': 3, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:03', 'name': 'Ge 0/3', 'port_number': 0, 'short_name': 'Ge 0/3'}, {'adapter_number': 4, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:04', 'name': 'Ge 0/4', 'port_number': 0, 'short_name': 'Ge 0/4'}, {'adapter_number': 5, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:05', 'name': 'Ge 0/5', 'port_number': 0, 'short_name': 'Ge 0/5'}, {'adapter_number': 6, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:06', 'name': 'Ge 0/6', 'port_number': 0, 'short_name': 'Ge 0/6'}, {'adapter_number': 7, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:07', 'name': 'Ge 0/7', 'port_number': 0, 'short_name': 'Ge 0/7'}, {'adapter_number': 8, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:08', 'name': 'Ge 0/8', 'port_number': 0, 'short_name': 'Ge 0/8'}, {'adapter_number': 9, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:09', 'name': 'Ge 0/9', 'port_number': 0, 'short_name': 'Ge 0/9'}, {'adapter_number': 10, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:0a', 'name': 'Ge 0/10', 'port_number': 0, 'short_name': 'Ge 0/10'}, {'adapter_number': 11, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:0b', 'name': 'Ge 0/11', 'port_number': 0, 'short_name': 'Ge 0/11'}, {'adapter_number': 12, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:0c', 'name': 'Ge 0/12', 'port_number': 0, 'short_name': 'Ge 0/12'}, {'adapter_number': 13, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:0d', 'name': 'Ge 0/13', 'port_number': 0, 'short_name': 'Ge 0/13'}, {'adapter_number': 14, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:0e', 'name': 'Ge 0/14', 'port_number': 0, 'short_name': 'Ge 0/14'}, {'adapter_number': 15, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:b9:fe:a5:00:0f', 'name': 'Ge 0/15', 'port_number': 0, 'short_name': 'Ge 0/15'}], 'x': 200, 'y': -200}, 'R-3': {'server': '127.0.0.1', 'name': 'R-3', 'node_id': 'ef782ded-ee4c-42c3-9db9-2a2fd4dc0552', 'console_port': 5004, 'console_type': 'telnet', 'type': 'qemu', 'ports': [{'adapter_number': 0, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:00', 'name': 'Ge 0/0', 'port_number': 0, 'short_name': 'Ge 0/0'}, {'adapter_number': 1, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:01', 'name': 'Ge 0/1', 'port_number': 0, 'short_name': 'Ge 0/1'}, {'adapter_number': 2, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:02', 'name': 'Ge 0/2', 'port_number': 0, 'short_name': 'Ge 0/2'}, {'adapter_number': 3, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:03', 'name': 'Ge 0/3', 'port_number': 0, 'short_name': 'Ge 0/3'}, {'adapter_number': 4, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:04', 'name': 'Ge 0/4', 'port_number': 0, 'short_name': 'Ge 0/4'}, {'adapter_number': 5, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:05', 'name': 'Ge 0/5', 'port_number': 0, 'short_name': 'Ge 0/5'}, {'adapter_number': 6, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:06', 'name': 'Ge 0/6', 'port_number': 0, 'short_name': 'Ge 0/6'}, {'adapter_number': 7, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:07', 'name': 'Ge 0/7', 'port_number': 0, 'short_name': 'Ge 0/7'}, {'adapter_number': 8, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:08', 'name': 'Ge 0/8', 'port_number': 0, 'short_name': 'Ge 0/8'}, {'adapter_number': 9, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:09', 'name': 'Ge 0/9', 'port_number': 0, 'short_name': 'Ge 0/9'}, {'adapter_number': 10, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:0a', 'name': 'Ge 0/10', 'port_number': 0, 'short_name': 'Ge 0/10'}, {'adapter_number': 11, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:0b', 'name': 'Ge 0/11', 'port_number': 0, 'short_name': 'Ge 0/11'}, {'adapter_number': 12, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:0c', 'name': 'Ge 0/12', 'port_number': 0, 'short_name': 'Ge 0/12'}, {'adapter_number': 13, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:0d', 'name': 'Ge 0/13', 'port_number': 0, 'short_name': 'Ge 0/13'}, {'adapter_number': 14, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:0e', 'name': 'Ge 0/14', 'port_number': 0, 'short_name': 'Ge 0/14'}, {'adapter_number': 15, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:78:2d:ed:00:0f', 'name': 'Ge 0/15', 'port_number': 0, 'short_name': 'Ge 0/15'}], 'x': -200, 'y': 200}, 'R-4': {'server': '127.0.0.1', 'name': 'R-4', 'node_id': '11069fb2-8c0b-455b-8b91-72ae92eae201', 'console_port': 5006, 'console_type': 'telnet', 'type': 'qemu', 'ports': [{'adapter_number': 0, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:00', 'name': 'Ge 0/0', 'port_number': 0, 'short_name': 'Ge 0/0'}, {'adapter_number': 1, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:01', 'name': 'Ge 0/1', 'port_number': 0, 'short_name': 'Ge 0/1'}, {'adapter_number': 2, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:02', 'name': 'Ge 0/2', 'port_number': 0, 'short_name': 'Ge 0/2'}, {'adapter_number': 3, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:03', 'name': 'Ge 0/3', 'port_number': 0, 'short_name': 'Ge 0/3'}, {'adapter_number': 4, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:04', 'name': 'Ge 0/4', 'port_number': 0, 'short_name': 'Ge 0/4'}, {'adapter_number': 5, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:05', 'name': 'Ge 0/5', 'port_number': 0, 'short_name': 'Ge 0/5'}, {'adapter_number': 6, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:06', 'name': 'Ge 0/6', 'port_number': 0, 'short_name': 'Ge 0/6'}, {'adapter_number': 7, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:07', 'name': 'Ge 0/7', 'port_number': 0, 'short_name': 'Ge 0/7'}, {'adapter_number': 8, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:08', 'name': 'Ge 0/8', 'port_number': 0, 'short_name': 'Ge 0/8'}, {'adapter_number': 9, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:09', 'name': 'Ge 0/9', 'port_number': 0, 'short_name': 'Ge 0/9'}, {'adapter_number': 10, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:0a', 'name': 'Ge 0/10', 'port_number': 0, 'short_name': 'Ge 0/10'}, {'adapter_number': 11, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:0b', 'name': 'Ge 0/11', 'port_number': 0, 'short_name': 'Ge 0/11'}, {'adapter_number': 12, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:0c', 'name': 'Ge 0/12', 'port_number': 0, 'short_name': 'Ge 0/12'}, {'adapter_number': 13, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:0d', 'name': 'Ge 0/13', 'port_number': 0, 'short_name': 'Ge 0/13'}, {'adapter_number': 14, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:0e', 'name': 'Ge 0/14', 'port_number': 0, 'short_name': 'Ge 0/14'}, {'adapter_number': 15, 'adapter_type': 'e1000', 'data_link_types': {'Ethernet': 'DLT_EN10MB'}, 'link_type': 'ethernet', 'mac_address': '0c:06:9f:b2:00:0f', 'name': 'Ge 0/15', 'port_number': 0, 'short_name': 'Ge 0/15'}], 'x': 200, 'y': 200}}, 'links': []}",
                tool_call_id="call_00_ISqGMOuC3dmodc2N1Mywcgty",
            )
        ]
    }
}

# %%
llm_calls_6 = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="Perfect! I have successfully created a topology with four Cisco routers in GNS3. Here's a summary of what was accomplished:\n\n## Topology Creation Complete ✅\n\n**Project Details:**\n- **Project Name:** test\n- **Project ID:** 365dd3ff-cda9-447a-94da-3a6cef75fe77\n- **Status:** Created but not started (as requested)\n\n**Created Routers:**\n1. **R-1** (Node ID: 6ec10265-c872-497a-8b73-1dc989c065e0)\n   - Position: (-200, -200)\n   - Console Port: 5000\n\n2. **R-2** (Node ID: f3b9fea5-dbff-4099-8e3b-b088c32f7a45)\n   - Position: (200, -200)\n   - Console Port: 5002\n\n3. **R-3** (Node ID: ef782ded-ee4c-42c3-9db9-2a2fd4dc0552)\n   - Position: (-200, 200)\n   - Console Port: 5004\n\n4. **R-4** (Node ID: 11069fb2-8c0b-455b-8b91-72ae92eae201)\n   - Position: (200, 200)\n   - Console Port: 5006\n\n**Device Specifications:**\n- All routers are Cisco IOSv devices\n- Each router has 16 Gigabit Ethernet interfaces (Ge 0/0 to Ge 0/15)\n- The routers are arranged in a square formation for easy visualization\n\n**Current Status:**\n- All routers are created but not started (as per your request)\n- No links are currently configured between the routers\n- The topology is ready for you to add connections and start when needed\n\nThe topology is now ready for you to configure interconnections, routing protocols, or any other network configurations you'd like to implement. When you're ready to start the routers, you can use the start command.",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 448,
                        "prompt_tokens": 10925,
                        "total_tokens": 11373,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 4544,
                        },
                        "prompt_cache_hit_tokens": 4544,
                        "prompt_cache_miss_tokens": 6381,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "4e236f44-0595-42cd-b5fe-003ee8b20a4c",
                    "finish_reason": "stop",
                    "logprobs": None,
                },
                id="lc_run--fc4cfd82-1c3e-4c0c-a5e5-d7e466df4ac6-0",
                usage_metadata={
                    "input_tokens": 10925,
                    "output_tokens": 448,
                    "total_tokens": 11373,
                    "input_token_details": {"cache_read": 4544},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 6,
    }
}

# %%
from langchain.messages import ToolMessage, HumanMessage, AIMessage
from pprint import pprint
import json

tool_calls = {
    "llm_call": {
        "messages": [
            AIMessage(
                content="Great! I can see the topology with R-1 through R-6 routers. Now let me check the IP configurations and routing to perform the ping test from R-1 to R-6.",
                additional_kwargs={"refusal": None},
                response_metadata={
                    "token_usage": {
                        "completion_tokens": 157,
                        "prompt_tokens": 5705,
                        "total_tokens": 5862,
                        "completion_tokens_details": None,
                        "prompt_tokens_details": {
                            "audio_tokens": None,
                            "cached_tokens": 5696,
                        },
                        "prompt_cache_hit_tokens": 5696,
                        "prompt_cache_miss_tokens": 9,
                    },
                    "model_provider": "deepseek",
                    "model_name": "deepseek-chat",
                    "system_fingerprint": "fp_ffc7281d48_prod0820_fp8_kvcache",
                    "id": "efd45c63-5067-482d-a5c9-346571677bc5",
                    "finish_reason": "tool_calls",
                    "logprobs": None,
                },
                id="lc_run--7fb777fb-3503-46cb-9875-c903eb698c25-0",
                tool_calls=[
                    {
                        "name": "execute_multiple_device_commands",
                        "args": {
                            "tool_input": '[\n    {\n        "device_name": "R-1",\n        "commands": ["show ip interface brief", "show ip route", "show running-config interface Ge 0/4"]\n    },\n    {\n        "device_name": "R-6", \n        "commands": ["show ip interface brief", "show ip route", "show running-config interface Ge 0/0"]\n    }\n]'
                        },
                        "id": "call_00_oFdyrzjV58CKb8tMdkji5FUT",
                        "type": "tool_call",
                    }
                ],
                usage_metadata={
                    "input_tokens": 5705,
                    "output_tokens": 157,
                    "total_tokens": 5862,
                    "input_token_details": {"cache_read": 5696},
                    "output_token_details": {},
                },
            )
        ],
        "llm_calls": 2,
    }
}

llm_call_data = tool_calls["llm_call"]
messages_list = llm_call_data["messages"]
aimessage_object = messages_list[0]
#pprint(aimessage_object)
content_value = aimessage_object.content
tooltool_calls_list = aimessage_object.tool_calls
#pprint(tooltool_calls_list)
pprint(json.dumps(tooltool_calls_list))
# Out:
# ('[{"name": "execute_multiple_device_commands", "args": {"tool_input": '
#  '"[\\n    {\\n        \\"device_name\\": \\"R-1\\",\\n        \\"commands\\": '
#  '[\\"show ip interface brief\\", \\"show ip route\\", \\"show running-config '
#  'interface Ge 0/4\\"]\\n    },\\n    {\\n        \\"device_name\\": '
#  '\\"R-6\\", \\n        \\"commands\\": [\\"show ip interface brief\\", '
#  '\\"show ip route\\", \\"show running-config interface Ge 0/0\\"]\\n    '
#  '}\\n]"}, "id": "call_00_oFdyrzjV58CKb8tMdkji5FUT", "type": "tool_call"}]')

# %%
content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
tool_calls=[{'name': 'execute_multiple_device_commands', 'args': {}, 'id': 'call_00_68LzD5GSHaGFEWS24c6zoL6Y', 'type': 'tool_call'}] 
tool_call_chunks=[{'name': 'execute_multiple_device_commands', 'args': '', 'id': 'call_00_68LzD5GSHaGFEWS24c6zoL6Y', 'index': 0, 'type': 'tool_call_chunk'}]


content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}] 
tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]


content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
invalid_tool_calls=[{'name': None, 'args': 'tool', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] 
tool_call_chunks=[{'name': None, 'args': 'tool', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]


content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
invalid_tool_calls=[{'name': None, 'args': '_input', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] 
tool_call_chunks=[{'name': None, 'args': '_input', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]

content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] 
tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]

content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
invalid_tool_calls=[{'name': None, 'args': ' "[', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] 
tool_call_chunks=[{'name': None, 'args': ' "[', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]

content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}] 
tool_call_chunks=[{'name': None, 'args': '{\\', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]

".........."

content='' 
additional_kwargs={} 
response_metadata={'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
invalid_tool_calls=[{'name': None, 'args': '"}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] 
tool_call_chunks=[{'name': None, 'args': '"}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]


content='' 
additional_kwargs={} 
response_metadata={'finish_reason': 'tool_calls', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'model_provider': 'deepseek'} 
id='lc_run--610f8d2f-5e49-4b73-8207-8b9d1ae0c01b' 
usage_metadata={'input_tokens': 5697, 'output_tokens': 119, 'total_tokens': 5816, 'input_token_details': {'cache_read': 5696}, 'output_token_details': {}} 
chunk_position='last'
