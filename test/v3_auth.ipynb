# %%
from custom_gns3fy import Gns3Connector

conn = Gns3Connector(
    url="http://192.168.88.98",
    user="admin",
    cred="admin",
    api_version=3
)

version = conn.get_version()
print(f"get_version: {version}")
print("---------------")
print(f"token: {conn.access_token}")
print("---------------")
#print(f"get_projects: {conn.get_projects()}")
#print("---------------")
#print(f"project_summary: {conn.projects_summary()}")
#print("---------------")
#print(f"get_project: {conn.get_project(name='network-ai')}")
#print("---------------")
#print(f"templates_summary: {conn.templates_summary()}")
#print("---------------")
#print(f"get_templates: {conn.get_templates()}")
#print("---------------")
#print(f"get_template : {conn.get_template(name='vpc')}")
#print("---------------")
print(f"get_nodes : {conn.get_nodes(project_id='a3ed1670-313e-4d82-8296-a74698ed8754')}")
print("---------------")
print(f"get_node : {conn.get_node(node_id='eb387f94-18fc-4076-8902-5c330e9a1588', project_id='a3ed1670-313e-4d82-8296-a74698ed8754')}")
print("---------------")
print(f"get_links : {conn.get_links(project_id='a3ed1670-313e-4d82-8296-a74698ed8754')}")
print("---------------")
print(f"get_link : {conn.get_link(project_id='a3ed1670-313e-4d82-8296-a74698ed8754', link_id='c2bc25c7-9cb9-461f-9158-9e8b67d611e2')}")
print("---------------")
print(f"get_computes : {conn.get_computes()}")
# Out:
# Successfully authenticated to v3 API, token obtained
# get_version: {'controller_host': '127.0.0.1', 'version': '3.0.5', 'local': False}
# ---------------
# token: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhZG1pbiIsImV4cCI6MTc2MTE0Njk5OX0.d5klHaUzzm7R1g-C9fXKhGKQ3Kn9dSwLrrbCdFj92kA
# ---------------
# ...
