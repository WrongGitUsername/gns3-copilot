# %%
from gns3_copilot.gns3_client.custom_gns3fy import Gns3Connector, Node
from pprint import pprint

conn = Gns3Connector(
    url= "http://127.0.0.1:3080/",
    user="",
    cred="",
    api_version=2
)

version = conn.get_version()
pprint(version)
# Out:
# {'local': True, 'version': '2.2.52'}

# %%
pprint(conn.get_projects())
# Out:
# [{'auto_close': True,
#   'auto_open': False,
#   'auto_start': False,
#   'drawing_grid_size': 25,
#   'filename': 'mylab.gns3',
#   'grid_size': 75,
#   'name': 'mylab',
#   'path': '/home/yueguobin/GNS3/projects/mylab',
#   'project_id': 'ff8e059c-c33d-47f4-bc11-c7dda8a1d500',
#   'scene_height': 1000,
#   'scene_width': 2000,
#   'show_grid': False,
#   'show_interface_labels': False,
#   'show_layers': False,
#   'snap_to_grid': False,
#   'status': 'closed',
#   'supplier': None,
#   'variables': None,
#   'zoom': 100},
#  {'auto_close': True,
#   'auto_open': False,
#   'auto_start': False,
#   'drawing_grid_size': 25,
#   'filename': 'q-learning-流量管理.gns3',
#   'grid_size': 75,
#   'name': 'q-learning-流量管理',
#   'path': '/home/yueguobin/GNS3/projects/q-learning-流量管理',
#   'project_id': '69d49a6a-ff7f-45dd-af1e-dc14aff600cc',
#   'scene_height': 1000,
#   'scene_width': 2000,
#   'show_grid': False,
#   'show_interface_labels': True,
#   'show_layers': False,
#   'snap_to_grid': False,
#   'status': 'closed',
#   'supplier': None,
#   'variables': None,
#   'zoom': 100},
#  {'auto_close': True,
#   'auto_open': False,
#   'auto_start': False,
#   'drawing_grid_size': 25,
#   'filename': 'network_ai.gns3',
#   'grid_size': 75,
#   'name': 'network_ai',
#   'path': '/home/yueguobin/GNS3/projects/network_ai',
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'scene_height': 1000,
#   'scene_width': 2000,
#   'show_grid': False,
#   'show_interface_labels': False,
#   'show_layers': False,
#   'snap_to_grid': True,
#   'status': 'opened',
#   'supplier': None,
#   'variables': None,
#   'zoom': 100},
#  {'auto_close': True,
#   'auto_open': False,
#   'auto_start': False,
#   'drawing_grid_size': 25,
#   'filename': 'test.gns3',
#   'grid_size': 75,
#   'name': 'test',
#   'path': '/home/yueguobin/GNS3/projects/test',
#   'project_id': '365dd3ff-cda9-447a-94da-3a6cef75fe77',
#   'scene_height': 1000,
#   'scene_width': 2000,
#   'show_grid': False,
#   'show_interface_labels': False,
#   'show_layers': False,
#   'snap_to_grid': False,
#   'status': 'closed',
#   'supplier': None,
#   'variables': None,
#   'zoom': 100},
#  {'auto_close': True,
#   'auto_open': False,
#   'auto_start': False,
#   'drawing_grid_size': 25,
#   'filename': 'Soft-RoCE learning.gns3',
#   'grid_size': 75,
#   'name': 'Soft-RoCE learning',
#   'path': '/home/yueguobin/GNS3/projects/Soft-RoCE learning',
#   'project_id': 'd1e4509e-64bd-4109-b954-266223959ee9',
#   'scene_height': 1000,
#   'scene_width': 2000,
#   'show_grid': False,
#   'show_interface_labels': False,
#   'show_layers': False,
#   'snap_to_grid': False,
#   'status': 'closed',
#   'supplier': None,
#   'variables': None,
#   'zoom': 100}]

# %%
pprint(conn.projects_summary(is_print=False))
# Out:
# [('mylab', 'ff8e059c-c33d-47f4-bc11-c7dda8a1d500', 0, 0, 'closed'),
#  ('q-learning-流量管理', '69d49a6a-ff7f-45dd-af1e-dc14aff600cc', 0, 0, 'closed'),
#  ('network_ai', 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210', 6, 8, 'opened'),
#  ('test', '365dd3ff-cda9-447a-94da-3a6cef75fe77', 0, 0, 'closed'),
#  ('Soft-RoCE learning', 'd1e4509e-64bd-4109-b954-266223959ee9', 0, 0, 'closed')]

# %%
pprint(conn.get_project(project_id="ff8e059c-c33d-47f4-bc11-c7dda8a1d500"))
# or 
#pprint(conn.get_project(name="untitled"))
# Out:
# {'auto_close': True,
#  'auto_open': False,
#  'auto_start': False,
#  'drawing_grid_size': 25,
#  'filename': 'mylab.gns3',
#  'grid_size': 75,
#  'name': 'mylab',
#  'path': '/home/yueguobin/GNS3/projects/mylab',
#  'project_id': 'ff8e059c-c33d-47f4-bc11-c7dda8a1d500',
#  'scene_height': 1000,
#  'scene_width': 2000,
#  'show_grid': False,
#  'show_interface_labels': False,
#  'show_layers': False,
#  'snap_to_grid': False,
#  'status': 'closed',
#  'supplier': None,
#  'variables': None,
#  'zoom': 100}

# %%
pprint(conn.templates_summary(is_print=False))
# Out:
# [('Cisco CSR1000v 17.3.8a',
#   'bed0539f-6a7e-42ed-94cd-9f46ea1ba2d0',
#   'qemu',
#   False,
#   'telnet',
#   'router'),
#  ('NXOS_9500v',
#   'dbe332ac-c130-458b-b4a1-b754c09a917e',
#   'qemu',
#   False,
#   'telnet',
#   'switch'),
#  ('c7200',
#   '7a5be161-fdbc-4577-8c7b-20da6451bae7',
#   'dynamips',
#   False,
#   'telnet',
#   'router'),
#  ('IOU_L2',
#   '3a66e68c-ac98-4230-8888-7a411e2798ca',
#   'iou',
#   False,
#   'telnet',
#   'switch'),
#  ('IOU_L3',
#   '684610fa-3fb3-453a-8099-0ebac9372102',
#   'iou',
#   False,
#   'telnet',
#   'router'),
#  ('IOSvL2',
#   '6050bbaa-d83f-47a9-9a30-458374b84aff',
#   'qemu',
#   False,
#   'telnet',
#   'switch'),
#  ('nxosv9300-93.x',
#   'cd45b1bb-04bd-4919-9765-7ee9fd08c30f',
#   'qemu',
#   False,
#   'telnet',
#   'switch'),
#  ('Ubuntu22.04',
#   '8088e57f-056f-4114-a180-0c63a6aef880',
#   'qemu',
#   False,
#   'telnet',
#   'guest'),
#  ('IOSv',
#   'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'qemu',
#   False,
#   'telnet',
#   'router'),
#  ('gns3-lab',
#   '702b79fe-15bd-43ec-ae6c-cb8cf39a9965',
#   'cloud',
#   False,
#   'N/A',
#   'guest'),
#  ('Cisco CSR1000v 16.12.3',
#   '43d064d0-4ebf-4394-87ba-b8c06aa516df',
#   'qemu',
#   False,
#   'telnet',
#   'router'),
#  ('nxosv9300-104.3F',
#   '76317608-bfe0-426a-8f21-beb274d1c61a',
#   'qemu',
#   False,
#   'telnet',
#   'switch'),
#  ('Debian 12.6 ',
#   'ec69be61-3f91-4a2f-8058-91d54fd71329',
#   'qemu',
#   False,
#   'telnet',
#   'guest'),
#  ('debian13',
#   '72c13d78-baf1-4813-9255-a7ac6950c6fc',
#   'qemu',
#   False,
#   'telnet',
#   'guest'),
#  ('c7200-120.28d',
#   '02f3ef2c-7061-4c8c-8453-9ed5be8edb40',
#   'dynamips',
#   False,
#   'telnet',
#   'router'),
#  ('c7200-1999',
#   '4e1d8aa1-2543-4fab-af27-3b1ee59db8d0',
#   'dynamips',
#   False,
#   'telnet',
#   'router'),
#  ('Cloud',
#   '39e257dc-8412-3174-b6b3-0ee3ed6a43e9',
#   'cloud',
#   True,
#   'N/A',
#   'guest'),
#  ('NAT', 'df8f4ea9-33b7-3e96-86a2-c39bc9bb649c', 'nat', True, 'N/A', 'guest'),
#  ('VPCS', '19021f99-e36f-394d-b4a1-8aaa902ab9cc', 'vpcs', True, 'N/A', 'guest'),
#  ('Ethernet switch',
#   '1966b864-93e7-32d5-965f-001384eec461',
#   'ethernet_switch',
#   True,
#   'none',
#   'switch'),
#  ('Ethernet hub',
#   'b4503ea9-d6b6-3695-9fe4-1db3b39290b0',
#   'ethernet_hub',
#   True,
#   'N/A',
#   'switch'),
#  ('Frame Relay switch',
#   'dd0f6f3a-ba58-3249-81cb-a1dd88407a47',
#   'frame_relay_switch',
#   True,
#   'N/A',
#   'switch'),
#  ('ATM switch',
#   'aaa764e2-b383-300f-8a0e-3493bbfdb7d2',
#   'atm_switch',
#   True,
#   'N/A',
#   'switch')]

# %%
pprint(conn.get_templates())
# Out:
# [{'adapter_type': 'vmxnet3',
#   'adapters': 10,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'router',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [{'adapter_number': 0, 'port_name': 'Ge 1'},
#                       {'adapter_number': 1, 'port_name': 'Ge 2'},
#                       {'adapter_number': 2, 'port_name': 'Ge 3'},
#                       {'adapter_number': 3, 'port_name': 'Ge 4'},
#                       {'adapter_number': 4, 'port_name': 'Ge 5'},
#                       {'adapter_number': 5, 'port_name': 'Ge 6'},
#                       {'adapter_number': 6, 'port_name': 'Ge 7'},
#                       {'adapter_number': 7, 'port_name': 'Ge 8'},
#                       {'adapter_number': 8, 'port_name': 'Ge 9'},
#                       {'adapter_number': 9, 'port_name': 'Ge 10'},
#                       {'adapter_number': 10, 'port_name': 'Ge 11'},
#                       {'adapter_number': 11, 'port_name': 'Ge 12'},
#                       {'adapter_number': 12, 'port_name': 'Ge 13'},
#                       {'adapter_number': 13, 'port_name': 'Ge 14'},
#                       {'adapter_number': 14, 'port_name': 'Ge 15'},
#                       {'adapter_number': 15, 'port_name': 'Ge 16'},
#                       {'adapter_number': 16, 'port_name': 'Ge 17'},
#                       {'adapter_number': 17, 'port_name': 'Ge 18'},
#                       {'adapter_number': 18, 'port_name': 'Ge 19'},
#                       {'adapter_number': 19, 'port_name': 'Ge 20'},
#                       {'adapter_number': 20, 'port_name': 'Ge 21'},
#                       {'adapter_number': 21, 'port_name': 'Ge 22'},
#                       {'adapter_number': 22, 'port_name': 'Ge 23'},
#                       {'adapter_number': 23, 'port_name': 'Ge 24'},
#                       {'adapter_number': 24, 'port_name': 'Ge 25'},
#                       {'adapter_number': 25, 'port_name': 'Ge 26'}],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': '/home/yueguobin/GNS3/images/QEMU/csr1000v-universalk9.17.03.08a-serial.qcow2',
#   'hda_disk_interface': 'ide',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'Cisco CSR1000v 17.3.8a',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Ge {1}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 3072,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/router_cloud.svg',
#   'template_id': 'bed0539f-6a7e-42ed-94cd-9f46ea1ba2d0',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Cloud Services Router 1000V'},
#  {'adapter_type': 'e1000',
#   'adapters': 25,
#   'bios_image': '/home/yueguobin/GNS3/images/QEMU/OVMF-edk2-stable202305.fd',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'switch',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 4,
#   'create_config_disk': False,
#   'custom_adapters': [{'adapter_number': 0, 'port_name': 'Mgmt0'}],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': '/home/yueguobin/GNS3/images/QEMU/nexus9500v64.10.4.3.F.qcow2',
#   'hda_disk_interface': 'sata',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'NXOS_9500v',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Ethernet1/{port0}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 10240,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/switch_multilayer.svg',
#   'template_id': 'dbe332ac-c130-458b-b4a1-b754c09a917e',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Cisco Nexus 9000v Switch\ncisco nexus 9500v 10.4.3.F'},
#  {'auto_delete_disks': True,
#   'builtin': False,
#   'category': 'router',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'default_name_format': 'R{0}',
#   'disk0': 0,
#   'disk1': 0,
#   'exec_area': 64,
#   'idlemax': 500,
#   'idlepc': '0x60189234',
#   'idlesleep': 30,
#   'image': 'c7200-adventerprisek9-mz.152-4.M11.image',
#   'mac_addr': '',
#   'midplane': 'vxr',
#   'mmap': True,
#   'name': 'c7200',
#   'npe': 'npe-400',
#   'nvram': 512,
#   'platform': 'c7200',
#   'private_config': '',
#   'ram': 256,
#   'slot0': 'C7200-IO-FE',
#   'slot1': 'PA-2FE-TX',
#   'slot2': 'PA-8E',
#   'slot3': '',
#   'slot4': '',
#   'slot5': '',
#   'slot6': '',
#   'sparsemem': True,
#   'startup_config': 'ios_base_startup-config.txt',
#   'symbol': ':/symbols/router.svg',
#   'system_id': 'FTX0945W0MY',
#   'template_id': '7a5be161-fdbc-4577-8c7b-20da6451bae7',
#   'template_type': 'dynamips',
#   'usage': ''},
#  {'builtin': False,
#   'category': 'switch',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'default_name_format': 'L2-iou-{0}',
#   'ethernet_adapters': 4,
#   'l1_keepalives': False,
#   'name': 'IOU_L2',
#   'nvram': 128,
#   'path': 'i86bi-linux-l2-adventerprisek9-15.1a.bin',
#   'private_config': '',
#   'ram': 256,
#   'serial_adapters': 0,
#   'startup_config': 'iou_l2_base_startup-config.txt',
#   'symbol': ':/symbols/affinity/square/blue/switch.svg',
#   'template_id': '3a66e68c-ac98-4230-8888-7a411e2798ca',
#   'template_type': 'iou',
#   'usage': '',
#   'use_default_iou_values': True},
#  {'builtin': False,
#   'category': 'router',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'default_name_format': 'L3-iou-{0}',
#   'ethernet_adapters': 2,
#   'l1_keepalives': False,
#   'name': 'IOU_L3',
#   'nvram': 128,
#   'path': 'i86bi-linux-l3-adventerprisek9-15.4.1T.bin',
#   'private_config': '',
#   'ram': 256,
#   'serial_adapters': 2,
#   'startup_config': 'iou_l3_base_startup-config.txt',
#   'symbol': ':/symbols/affinity/square/blue/router2.svg',
#   'template_id': '684610fa-3fb3-453a-8099-0ebac9372102',
#   'template_type': 'iou',
#   'usage': '',
#   'use_default_iou_values': True},
#  {'adapter_type': 'e1000',
#   'adapters': 16,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'switch',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': '/home/yueguobin/GNS3/images/QEMU/vios_l2-adventerprisek9-m.ssa.high_iron_20200929.qcow2',
#   'hda_disk_interface': 'virtio',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'IOSvL2',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Gi{1}/{0}',
#   'port_segment_size': 4,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 768,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/switch.svg',
#   'template_id': '6050bbaa-d83f-47a9-9a30-458374b84aff',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Cisco IOSv Virtual Switch Platform'},
#  {'adapter_type': 'e1000',
#   'adapters': 33,
#   'bios_image': '/home/yueguobin/GNS3/images/QEMU/OVMF-edk2-stable202305.fd',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'switch',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 2,
#   'create_config_disk': False,
#   'custom_adapters': [{'adapter_number': 0, 'port_name': 'Mgmt0'}],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': 'nexus9300v.9.3.6.qcow2',
#   'hda_disk_interface': 'sata',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'nxosv9300-93.x',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Eth1/{port0}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/bin/qemu-system-x86_64',
#   'ram': 6144,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/switch_multilayer.svg',
#   'template_id': 'cd45b1bb-04bd-4919-9765-7ee9fd08c30f',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Cisco Nexus 9000v Switch\ncisco nexus 9300v 9.3.6'},
#  {'adapter_type': 'virtio-net-pci',
#   'adapters': 1,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'guest',
#   'cdrom_image': 'ubuntu-cloud-init-data.iso',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': 'ubuntu-22.04-server-cloudimg-amd64.img',
#   'hda_disk_interface': 'virtio',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'Ubuntu22.04',
#   'on_close': 'power_off',
#   'options': '-nographic',
#   'platform': 'i386',
#   'port_name_format': 'Ethernet{0}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 1024,
#   'replicate_network_connection_state': True,
#   'symbol': 'distributor-logo-ubuntu.svg',
#   'template_id': '8088e57f-056f-4114-a180-0c63a6aef880',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Username: ubuntu\nPassword: ubuntu'},
#  {'adapter_type': 'e1000',
#   'adapters': 16,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'router',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [],
#   'default_name_format': 'R-{0}',
#   'first_port_name': '',
#   'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#   'hda_disk_interface': 'virtio',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'IOSv',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Ge 0/{0}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 512,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Cisco IOSv Virtual Router Platform'},
#  {'builtin': False,
#   'category': 'guest',
#   'compute_id': 'local',
#   'default_name_format': 'gns3-lab-{0}',
#   'name': 'gns3-lab',
#   'ports_mapping': [{'interface': 'virbr2',
#                      'name': 'virbr2',
#                      'port_number': 0,
#                      'type': 'ethernet'}],
#   'remote_console_host': '127.0.0.1',
#   'remote_console_http_path': '/',
#   'remote_console_port': 23,
#   'remote_console_type': 'none',
#   'symbol': 'icloud.svg',
#   'template_id': '702b79fe-15bd-43ec-ae6c-cb8cf39a9965',
#   'template_type': 'cloud'},
#  {'adapter_type': 'vmxnet3',
#   'adapters': 10,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'router',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': 'csr1000v-universalk9.16.12.03-serial.qcow2',
#   'hda_disk_interface': 'ide',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'Cisco CSR1000v 16.12.3',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Gi{port1}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/bin/qemu-system-x86_64',
#   'ram': 3072,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/router_cloud.svg',
#   'template_id': '43d064d0-4ebf-4394-87ba-b8c06aa516df',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'There is no default password and enable password. A default '
#            'configuration is present.'},
#  {'adapter_type': 'e1000',
#   'adapters': 33,
#   'bios_image': '/home/yueguobin/GNS3/images/QEMU/OVMF-edk2-stable202305.fd',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'switch',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 50,
#   'cpus': 4,
#   'create_config_disk': False,
#   'custom_adapters': [{'adapter_number': 0, 'port_name': 'Mgmt0'}],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': '/home/yueguobin/GNS3/images/QEMU/nexus9300v64.10.4.3.F.qcow2',
#   'hda_disk_interface': 'sata',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'nxosv9300-104.3F',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'Eth1/{port0}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/bin/qemu-system-x86_64',
#   'ram': 10240,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/square/blue/switch_multilayer.svg',
#   'template_id': '76317608-bfe0-426a-8f21-beb274d1c61a',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Cisco Nexus 9000v Switch\ncisco nexus 9300v 10.4.3.F'},
#  {'adapter_type': 'virtio-net-pci',
#   'adapters': 1,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'guest',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': 'debian-12.6.qcow2',
#   'hda_disk_interface': 'scsi',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'Debian 12.6 ',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'ens{port4}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 512,
#   'replicate_network_connection_state': True,
#   'symbol': ':/symbols/affinity/circle/blue/server.svg',
#   'template_id': 'ec69be61-3f91-4a2f-8058-91d54fd71329',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'Username:\tdebian\n'
#            'Password:\tdebian\n'
#            'To become root, use "sudo -s".'},
#  {'adapter_type': 'virtio-net-pci',
#   'adapters': 1,
#   'bios_image': '',
#   'boot_priority': 'c',
#   'builtin': False,
#   'category': 'guest',
#   'cdrom_image': '',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'cpu_throttling': 0,
#   'cpus': 1,
#   'create_config_disk': False,
#   'custom_adapters': [],
#   'default_name_format': '{name}-{0}',
#   'first_port_name': '',
#   'hda_disk_image': 'debian13-mini-final.qcow2',
#   'hda_disk_interface': 'virtio',
#   'hdb_disk_image': '',
#   'hdb_disk_interface': 'none',
#   'hdc_disk_image': '',
#   'hdc_disk_interface': 'none',
#   'hdd_disk_image': '',
#   'hdd_disk_interface': 'none',
#   'initrd': '',
#   'kernel_command_line': '',
#   'kernel_image': '',
#   'legacy_networking': False,
#   'linked_clone': True,
#   'mac_address': None,
#   'name': 'debian13',
#   'on_close': 'power_off',
#   'options': '',
#   'platform': '',
#   'port_name_format': 'ens{port3}',
#   'port_segment_size': 0,
#   'process_priority': 'normal',
#   'qemu_path': '/usr/bin/qemu-system-x86_64',
#   'ram': 512,
#   'replicate_network_connection_state': True,
#   'symbol': 'debian.svg',
#   'template_id': '72c13d78-baf1-4813-9255-a7ac6950c6fc',
#   'template_type': 'qemu',
#   'tpm': False,
#   'uefi': False,
#   'usage': 'debian/debian\n\nroot/debian'},
#  {'auto_delete_disks': True,
#   'builtin': False,
#   'category': 'router',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'default_name_format': 'R{0}',
#   'disk0': 0,
#   'disk1': 0,
#   'exec_area': 64,
#   'idlemax': 500,
#   'idlepc': '',
#   'idlesleep': 30,
#   'image': '/home/yueguobin/GNS3/images/IOS/c7200-is-mz.120-28d.image',
#   'mac_addr': '',
#   'midplane': 'vxr',
#   'mmap': True,
#   'name': 'c7200-120.28d',
#   'npe': 'npe-200',
#   'nvram': 512,
#   'platform': 'c7200',
#   'private_config': '',
#   'ram': 512,
#   'slot0': 'C7200-IO-FE',
#   'slot1': 'PA-2FE-TX',
#   'slot2': '',
#   'slot3': '',
#   'slot4': '',
#   'slot5': '',
#   'slot6': '',
#   'sparsemem': True,
#   'startup_config': 'ios_base_startup-config.txt',
#   'symbol': ':/symbols/router.svg',
#   'system_id': 'FTX0945W0MY',
#   'template_id': '02f3ef2c-7061-4c8c-8453-9ed5be8edb40',
#   'template_type': 'dynamips',
#   'usage': ''},
#  {'auto_delete_disks': True,
#   'builtin': False,
#   'category': 'router',
#   'compute_id': 'local',
#   'console_auto_start': False,
#   'console_type': 'telnet',
#   'default_name_format': 'R{0}',
#   'disk0': 0,
#   'disk1': 0,
#   'exec_area': 64,
#   'idlemax': 500,
#   'idlepc': '',
#   'idlesleep': 30,
#   'image': 'c7200-is-mz.19991126.image',
#   'mac_addr': '',
#   'midplane': 'vxr',
#   'mmap': True,
#   'name': 'c7200-1999',
#   'npe': 'npe-100',
#   'nvram': 512,
#   'platform': 'c7200',
#   'private_config': '',
#   'ram': 512,
#   'slot0': 'C7200-IO-FE',
#   'slot1': 'PA-2FE-TX',
#   'slot2': '',
#   'slot3': '',
#   'slot4': '',
#   'slot5': '',
#   'slot6': '',
#   'sparsemem': True,
#   'startup_config': '',
#   'symbol': ':/symbols/router.svg',
#   'system_id': 'FTX0945W0MY',
#   'template_id': '4e1d8aa1-2543-4fab-af27-3b1ee59db8d0',
#   'template_type': 'dynamips',
#   'usage': ''},
#  {'builtin': True,
#   'category': 'guest',
#   'compute_id': None,
#   'default_name_format': 'Cloud{0}',
#   'name': 'Cloud',
#   'symbol': ':/symbols/cloud.svg',
#   'template_id': '39e257dc-8412-3174-b6b3-0ee3ed6a43e9',
#   'template_type': 'cloud'},
#  {'builtin': True,
#   'category': 'guest',
#   'compute_id': None,
#   'default_name_format': 'NAT{0}',
#   'name': 'NAT',
#   'symbol': ':/symbols/nat.svg',
#   'template_id': 'df8f4ea9-33b7-3e96-86a2-c39bc9bb649c',
#   'template_type': 'nat'},
#  {'builtin': True,
#   'category': 'guest',
#   'compute_id': None,
#   'default_name_format': 'PC{0}',
#   'name': 'VPCS',
#   'properties': {'base_script_file': 'vpcs_base_config.txt'},
#   'symbol': ':/symbols/vpcs_guest.svg',
#   'template_id': '19021f99-e36f-394d-b4a1-8aaa902ab9cc',
#   'template_type': 'vpcs'},
#  {'builtin': True,
#   'category': 'switch',
#   'compute_id': None,
#   'console_type': 'none',
#   'default_name_format': 'Switch{0}',
#   'name': 'Ethernet switch',
#   'symbol': ':/symbols/ethernet_switch.svg',
#   'template_id': '1966b864-93e7-32d5-965f-001384eec461',
#   'template_type': 'ethernet_switch'},
#  {'builtin': True,
#   'category': 'switch',
#   'compute_id': None,
#   'default_name_format': 'Hub{0}',
#   'name': 'Ethernet hub',
#   'symbol': ':/symbols/hub.svg',
#   'template_id': 'b4503ea9-d6b6-3695-9fe4-1db3b39290b0',
#   'template_type': 'ethernet_hub'},
#  {'builtin': True,
#   'category': 'switch',
#   'compute_id': None,
#   'default_name_format': 'FRSW{0}',
#   'name': 'Frame Relay switch',
#   'symbol': ':/symbols/frame_relay_switch.svg',
#   'template_id': 'dd0f6f3a-ba58-3249-81cb-a1dd88407a47',
#   'template_type': 'frame_relay_switch'},
#  {'builtin': True,
#   'category': 'switch',
#   'compute_id': None,
#   'default_name_format': 'ATMSW{0}',
#   'name': 'ATM switch',
#   'symbol': ':/symbols/atm_switch.svg',
#   'template_id': 'aaa764e2-b383-300f-8a0e-3493bbfdb7d2',
#   'template_type': 'atm_switch'}]

# %%
pprint(conn.get_template(template_id='b4503ea9-d6b6-3695-9fe4-1db3b39290b0'))
# Out:
# {'builtin': True,
#  'category': 'switch',
#  'compute_id': None,
#  'default_name_format': 'Hub{0}',
#  'name': 'Ethernet hub',
#  'symbol': ':/symbols/hub.svg',
#  'template_id': 'b4503ea9-d6b6-3695-9fe4-1db3b39290b0',
#  'template_type': 'ethernet_hub'}

# %%
pprint(conn.get_nodes(project_id='f2f7ed27-7aa3-4b11-a64c-da947a2c7210'))
# Out:
# [{'command_line': '/usr/bin/qemu-system-x86_64 -name R-1 -m 512M -smp '
#                   'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                   '-drive '
#                   'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/dae0b5be-03aa-492d-939c-72f2bbe1d74a/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                   '-uuid dae0b5be-03aa-492d-939c-72f2bbe1d74a -serial '
#                   'telnet:127.0.0.1:5000,server,nowait -monitor '
#                   'tcp:127.0.0.1:45881,server,nowait -net none -device '
#                   'e1000,mac=0c:e0:b5:be:00:00,netdev=gns3-0 -netdev '
#                   'socket,id=gns3-0,udp=127.0.0.1:10081,localaddr=127.0.0.1:10080 '
#                   '-device e1000,mac=0c:e0:b5:be:00:01,netdev=gns3-1 -netdev '
#                   'socket,id=gns3-1,udp=127.0.0.1:10083,localaddr=127.0.0.1:10082 '
#                   '-device e1000,mac=0c:e0:b5:be:00:02,netdev=gns3-2 -netdev '
#                   'socket,id=gns3-2,udp=127.0.0.1:10085,localaddr=127.0.0.1:10084 '
#                   '-device e1000,mac=0c:e0:b5:be:00:03,netdev=gns3-3 -netdev '
#                   'socket,id=gns3-3,udp=127.0.0.1:10087,localaddr=127.0.0.1:10086 '
#                   '-device e1000,mac=0c:e0:b5:be:00:04,netdev=gns3-4 -netdev '
#                   'socket,id=gns3-4,udp=127.0.0.1:10089,localaddr=127.0.0.1:10088 '
#                   '-device e1000,mac=0c:e0:b5:be:00:05,netdev=gns3-5 -netdev '
#                   'socket,id=gns3-5,udp=127.0.0.1:10091,localaddr=127.0.0.1:10090 '
#                   '-device e1000,mac=0c:e0:b5:be:00:06,netdev=gns3-6 -netdev '
#                   'socket,id=gns3-6,udp=127.0.0.1:10093,localaddr=127.0.0.1:10092 '
#                   '-device e1000,mac=0c:e0:b5:be:00:07,netdev=gns3-7 -netdev '
#                   'socket,id=gns3-7,udp=127.0.0.1:10095,localaddr=127.0.0.1:10094 '
#                   '-device e1000,mac=0c:e0:b5:be:00:08,netdev=gns3-8 -netdev '
#                   'socket,id=gns3-8,udp=127.0.0.1:10097,localaddr=127.0.0.1:10096 '
#                   '-device e1000,mac=0c:e0:b5:be:00:09,netdev=gns3-9 -netdev '
#                   'socket,id=gns3-9,udp=127.0.0.1:10099,localaddr=127.0.0.1:10098 '
#                   '-device e1000,mac=0c:e0:b5:be:00:0a,netdev=gns3-10 -netdev '
#                   'socket,id=gns3-10,udp=127.0.0.1:10101,localaddr=127.0.0.1:10100 '
#                   '-device e1000,mac=0c:e0:b5:be:00:0b,netdev=gns3-11 -netdev '
#                   'socket,id=gns3-11,udp=127.0.0.1:10103,localaddr=127.0.0.1:10102 '
#                   '-device e1000,mac=0c:e0:b5:be:00:0c,netdev=gns3-12 -netdev '
#                   'socket,id=gns3-12,udp=127.0.0.1:10105,localaddr=127.0.0.1:10104 '
#                   '-device e1000,mac=0c:e0:b5:be:00:0d,netdev=gns3-13 -netdev '
#                   'socket,id=gns3-13,udp=127.0.0.1:10107,localaddr=127.0.0.1:10106 '
#                   '-device e1000,mac=0c:e0:b5:be:00:0e,netdev=gns3-14 -netdev '
#                   'socket,id=gns3-14,udp=127.0.0.1:10109,localaddr=127.0.0.1:10108 '
#                   '-device e1000,mac=0c:e0:b5:be:00:0f,netdev=gns3-15 -netdev '
#                   'socket,id=gns3-15,udp=127.0.0.1:10111,localaddr=127.0.0.1:10110 '
#                   '-display none',
#   'compute_id': 'local',
#   'console': 5012,
#   'console_auto_start': False,
#   'console_host': '0.0.0.0',
#   'console_type': 'telnet',
#   'custom_adapters': [],
#   'first_port_name': '',
#   'height': 60,
#   'label': {'rotation': 0,
#             'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                      'bold;fill: #000000;fill-opacity: 1.0;',
#             'text': 'R-1',
#             'x': 15,
#             'y': -25},
#   'locked': False,
#   'name': 'R-1',
#   'node_directory': '/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/dae0b5be-03aa-492d-939c-72f2bbe1d74a',
#   'node_id': 'dae0b5be-03aa-492d-939c-72f2bbe1d74a',
#   'node_type': 'qemu',
#   'port_name_format': 'Ge 0/{0}',
#   'port_segment_size': 0,
#   'ports': [{'adapter_number': 0,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:00',
#              'name': 'Ge 0/0',
#              'port_number': 0,
#              'short_name': 'Ge 0/0'},
#             {'adapter_number': 1,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:01',
#              'name': 'Ge 0/1',
#              'port_number': 0,
#              'short_name': 'Ge 0/1'},
#             {'adapter_number': 2,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:02',
#              'name': 'Ge 0/2',
#              'port_number': 0,
#              'short_name': 'Ge 0/2'},
#             {'adapter_number': 3,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:03',
#              'name': 'Ge 0/3',
#              'port_number': 0,
#              'short_name': 'Ge 0/3'},
#             {'adapter_number': 4,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:04',
#              'name': 'Ge 0/4',
#              'port_number': 0,
#              'short_name': 'Ge 0/4'},
#             {'adapter_number': 5,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:05',
#              'name': 'Ge 0/5',
#              'port_number': 0,
#              'short_name': 'Ge 0/5'},
#             {'adapter_number': 6,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:06',
#              'name': 'Ge 0/6',
#              'port_number': 0,
#              'short_name': 'Ge 0/6'},
#             {'adapter_number': 7,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:07',
#              'name': 'Ge 0/7',
#              'port_number': 0,
#              'short_name': 'Ge 0/7'},
#             {'adapter_number': 8,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:08',
#              'name': 'Ge 0/8',
#              'port_number': 0,
#              'short_name': 'Ge 0/8'},
#             {'adapter_number': 9,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:09',
#              'name': 'Ge 0/9',
#              'port_number': 0,
#              'short_name': 'Ge 0/9'},
#             {'adapter_number': 10,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:0a',
#              'name': 'Ge 0/10',
#              'port_number': 0,
#              'short_name': 'Ge 0/10'},
#             {'adapter_number': 11,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:0b',
#              'name': 'Ge 0/11',
#              'port_number': 0,
#              'short_name': 'Ge 0/11'},
#             {'adapter_number': 12,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:0c',
#              'name': 'Ge 0/12',
#              'port_number': 0,
#              'short_name': 'Ge 0/12'},
#             {'adapter_number': 13,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:0d',
#              'name': 'Ge 0/13',
#              'port_number': 0,
#              'short_name': 'Ge 0/13'},
#             {'adapter_number': 14,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:0e',
#              'name': 'Ge 0/14',
#              'port_number': 0,
#              'short_name': 'Ge 0/14'},
#             {'adapter_number': 15,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:e0:b5:be:00:0f',
#              'name': 'Ge 0/15',
#              'port_number': 0,
#              'short_name': 'Ge 0/15'}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'properties': {'adapter_type': 'e1000',
#                  'adapters': 16,
#                  'bios_image': '',
#                  'bios_image_md5sum': None,
#                  'boot_priority': 'c',
#                  'cdrom_image': '',
#                  'cdrom_image_md5sum': None,
#                  'cpu_throttling': 0,
#                  'cpus': 1,
#                  'create_config_disk': False,
#                  'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                  'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                  'hda_disk_interface': 'virtio',
#                  'hdb_disk_image': '',
#                  'hdb_disk_image_md5sum': None,
#                  'hdb_disk_interface': 'none',
#                  'hdc_disk_image': '',
#                  'hdc_disk_image_md5sum': None,
#                  'hdc_disk_interface': 'none',
#                  'hdd_disk_image': '',
#                  'hdd_disk_image_md5sum': None,
#                  'hdd_disk_interface': 'none',
#                  'initrd': '',
#                  'initrd_md5sum': None,
#                  'kernel_command_line': '',
#                  'kernel_image': '',
#                  'kernel_image_md5sum': None,
#                  'legacy_networking': False,
#                  'linked_clone': True,
#                  'mac_address': '0c:e0:b5:be:00:00',
#                  'on_close': 'power_off',
#                  'options': '',
#                  'platform': 'x86_64',
#                  'process_priority': 'normal',
#                  'qemu_path': '/usr/bin/qemu-system-x86_64',
#                  'ram': 512,
#                  'replicate_network_connection_state': True,
#                  'tpm': False,
#                  'uefi': False,
#                  'usage': 'Cisco IOSv Virtual Router Platform'},
#   'status': 'started',
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'width': 60,
#   'x': -30,
#   'y': -405,
#   'z': 1},
#  {'command_line': '/usr/bin/qemu-system-x86_64 -name R-2 -m 512M -smp '
#                   'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                   '-drive '
#                   'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/770c835c-83ae-42ce-a2b9-9a88fb4d2145/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                   '-uuid 770c835c-83ae-42ce-a2b9-9a88fb4d2145 -serial '
#                   'telnet:127.0.0.1:5001,server,nowait -monitor '
#                   'tcp:127.0.0.1:41229,server,nowait -net none -device '
#                   'e1000,mac=0c:0c:83:5c:00:00,netdev=gns3-0 -netdev '
#                   'socket,id=gns3-0,udp=127.0.0.1:10049,localaddr=127.0.0.1:10048 '
#                   '-device e1000,mac=0c:0c:83:5c:00:01,netdev=gns3-1 -netdev '
#                   'socket,id=gns3-1,udp=127.0.0.1:10051,localaddr=127.0.0.1:10050 '
#                   '-device e1000,mac=0c:0c:83:5c:00:02,netdev=gns3-2 -netdev '
#                   'socket,id=gns3-2,udp=127.0.0.1:10053,localaddr=127.0.0.1:10052 '
#                   '-device e1000,mac=0c:0c:83:5c:00:03,netdev=gns3-3 -netdev '
#                   'socket,id=gns3-3,udp=127.0.0.1:10055,localaddr=127.0.0.1:10054 '
#                   '-device e1000,mac=0c:0c:83:5c:00:04,netdev=gns3-4 -netdev '
#                   'socket,id=gns3-4,udp=127.0.0.1:10057,localaddr=127.0.0.1:10056 '
#                   '-device e1000,mac=0c:0c:83:5c:00:05,netdev=gns3-5 -netdev '
#                   'socket,id=gns3-5,udp=127.0.0.1:10059,localaddr=127.0.0.1:10058 '
#                   '-device e1000,mac=0c:0c:83:5c:00:06,netdev=gns3-6 -netdev '
#                   'socket,id=gns3-6,udp=127.0.0.1:10061,localaddr=127.0.0.1:10060 '
#                   '-device e1000,mac=0c:0c:83:5c:00:07,netdev=gns3-7 -netdev '
#                   'socket,id=gns3-7,udp=127.0.0.1:10063,localaddr=127.0.0.1:10062 '
#                   '-device e1000,mac=0c:0c:83:5c:00:08,netdev=gns3-8 -netdev '
#                   'socket,id=gns3-8,udp=127.0.0.1:10065,localaddr=127.0.0.1:10064 '
#                   '-device e1000,mac=0c:0c:83:5c:00:09,netdev=gns3-9 -netdev '
#                   'socket,id=gns3-9,udp=127.0.0.1:10067,localaddr=127.0.0.1:10066 '
#                   '-device e1000,mac=0c:0c:83:5c:00:0a,netdev=gns3-10 -netdev '
#                   'socket,id=gns3-10,udp=127.0.0.1:10069,localaddr=127.0.0.1:10068 '
#                   '-device e1000,mac=0c:0c:83:5c:00:0b,netdev=gns3-11 -netdev '
#                   'socket,id=gns3-11,udp=127.0.0.1:10071,localaddr=127.0.0.1:10070 '
#                   '-device e1000,mac=0c:0c:83:5c:00:0c,netdev=gns3-12 -netdev '
#                   'socket,id=gns3-12,udp=127.0.0.1:10073,localaddr=127.0.0.1:10072 '
#                   '-device e1000,mac=0c:0c:83:5c:00:0d,netdev=gns3-13 -netdev '
#                   'socket,id=gns3-13,udp=127.0.0.1:10075,localaddr=127.0.0.1:10074 '
#                   '-device e1000,mac=0c:0c:83:5c:00:0e,netdev=gns3-14 -netdev '
#                   'socket,id=gns3-14,udp=127.0.0.1:10077,localaddr=127.0.0.1:10076 '
#                   '-device e1000,mac=0c:0c:83:5c:00:0f,netdev=gns3-15 -netdev '
#                   'socket,id=gns3-15,udp=127.0.0.1:10079,localaddr=127.0.0.1:10078 '
#                   '-display none',
#   'compute_id': 'local',
#   'console': 5014,
#   'console_auto_start': False,
#   'console_host': '0.0.0.0',
#   'console_type': 'telnet',
#   'custom_adapters': [],
#   'first_port_name': '',
#   'height': 60,
#   'label': {'rotation': 0,
#             'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                      'bold;fill: #000000;fill-opacity: 1.0;',
#             'text': 'R-2',
#             'x': -31,
#             'y': 7},
#   'locked': False,
#   'name': 'R-2',
#   'node_directory': '/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#   'node_id': '770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#   'node_type': 'qemu',
#   'port_name_format': 'Ge 0/{0}',
#   'port_segment_size': 0,
#   'ports': [{'adapter_number': 0,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:00',
#              'name': 'Ge 0/0',
#              'port_number': 0,
#              'short_name': 'Ge 0/0'},
#             {'adapter_number': 1,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:01',
#              'name': 'Ge 0/1',
#              'port_number': 0,
#              'short_name': 'Ge 0/1'},
#             {'adapter_number': 2,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:02',
#              'name': 'Ge 0/2',
#              'port_number': 0,
#              'short_name': 'Ge 0/2'},
#             {'adapter_number': 3,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:03',
#              'name': 'Ge 0/3',
#              'port_number': 0,
#              'short_name': 'Ge 0/3'},
#             {'adapter_number': 4,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:04',
#              'name': 'Ge 0/4',
#              'port_number': 0,
#              'short_name': 'Ge 0/4'},
#             {'adapter_number': 5,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:05',
#              'name': 'Ge 0/5',
#              'port_number': 0,
#              'short_name': 'Ge 0/5'},
#             {'adapter_number': 6,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:06',
#              'name': 'Ge 0/6',
#              'port_number': 0,
#              'short_name': 'Ge 0/6'},
#             {'adapter_number': 7,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:07',
#              'name': 'Ge 0/7',
#              'port_number': 0,
#              'short_name': 'Ge 0/7'},
#             {'adapter_number': 8,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:08',
#              'name': 'Ge 0/8',
#              'port_number': 0,
#              'short_name': 'Ge 0/8'},
#             {'adapter_number': 9,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:09',
#              'name': 'Ge 0/9',
#              'port_number': 0,
#              'short_name': 'Ge 0/9'},
#             {'adapter_number': 10,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:0a',
#              'name': 'Ge 0/10',
#              'port_number': 0,
#              'short_name': 'Ge 0/10'},
#             {'adapter_number': 11,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:0b',
#              'name': 'Ge 0/11',
#              'port_number': 0,
#              'short_name': 'Ge 0/11'},
#             {'adapter_number': 12,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:0c',
#              'name': 'Ge 0/12',
#              'port_number': 0,
#              'short_name': 'Ge 0/12'},
#             {'adapter_number': 13,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:0d',
#              'name': 'Ge 0/13',
#              'port_number': 0,
#              'short_name': 'Ge 0/13'},
#             {'adapter_number': 14,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:0e',
#              'name': 'Ge 0/14',
#              'port_number': 0,
#              'short_name': 'Ge 0/14'},
#             {'adapter_number': 15,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0c:83:5c:00:0f',
#              'name': 'Ge 0/15',
#              'port_number': 0,
#              'short_name': 'Ge 0/15'}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'properties': {'adapter_type': 'e1000',
#                  'adapters': 16,
#                  'bios_image': '',
#                  'bios_image_md5sum': None,
#                  'boot_priority': 'c',
#                  'cdrom_image': '',
#                  'cdrom_image_md5sum': None,
#                  'cpu_throttling': 0,
#                  'cpus': 1,
#                  'create_config_disk': False,
#                  'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                  'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                  'hda_disk_interface': 'virtio',
#                  'hdb_disk_image': '',
#                  'hdb_disk_image_md5sum': None,
#                  'hdb_disk_interface': 'none',
#                  'hdc_disk_image': '',
#                  'hdc_disk_image_md5sum': None,
#                  'hdc_disk_interface': 'none',
#                  'hdd_disk_image': '',
#                  'hdd_disk_image_md5sum': None,
#                  'hdd_disk_interface': 'none',
#                  'initrd': '',
#                  'initrd_md5sum': None,
#                  'kernel_command_line': '',
#                  'kernel_image': '',
#                  'kernel_image_md5sum': None,
#                  'legacy_networking': False,
#                  'linked_clone': True,
#                  'mac_address': '0c:0c:83:5c:00:00',
#                  'on_close': 'power_off',
#                  'options': '',
#                  'platform': 'x86_64',
#                  'process_priority': 'normal',
#                  'qemu_path': '/usr/bin/qemu-system-x86_64',
#                  'ram': 512,
#                  'replicate_network_connection_state': True,
#                  'tpm': False,
#                  'uefi': False,
#                  'usage': 'Cisco IOSv Virtual Router Platform'},
#   'status': 'started',
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'width': 60,
#   'x': -30,
#   'y': -255,
#   'z': 1},
#  {'command_line': '/usr/bin/qemu-system-x86_64 -name R-3 -m 512M -smp '
#                   'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                   '-drive '
#                   'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/5f875fef-f795-4f06-96b2-9c34a66a296d/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                   '-uuid 5f875fef-f795-4f06-96b2-9c34a66a296d -serial '
#                   'telnet:127.0.0.1:5002,server,nowait -monitor '
#                   'tcp:127.0.0.1:45323,server,nowait -net none -device '
#                   'e1000,mac=0c:87:5f:ef:00:00,netdev=gns3-0 -netdev '
#                   'socket,id=gns3-0,udp=127.0.0.1:10017,localaddr=127.0.0.1:10016 '
#                   '-device e1000,mac=0c:87:5f:ef:00:01,netdev=gns3-1 -netdev '
#                   'socket,id=gns3-1,udp=127.0.0.1:10019,localaddr=127.0.0.1:10018 '
#                   '-device e1000,mac=0c:87:5f:ef:00:02,netdev=gns3-2 -netdev '
#                   'socket,id=gns3-2,udp=127.0.0.1:10021,localaddr=127.0.0.1:10020 '
#                   '-device e1000,mac=0c:87:5f:ef:00:03,netdev=gns3-3 -netdev '
#                   'socket,id=gns3-3,udp=127.0.0.1:10023,localaddr=127.0.0.1:10022 '
#                   '-device e1000,mac=0c:87:5f:ef:00:04,netdev=gns3-4 -netdev '
#                   'socket,id=gns3-4,udp=127.0.0.1:10025,localaddr=127.0.0.1:10024 '
#                   '-device e1000,mac=0c:87:5f:ef:00:05,netdev=gns3-5 -netdev '
#                   'socket,id=gns3-5,udp=127.0.0.1:10027,localaddr=127.0.0.1:10026 '
#                   '-device e1000,mac=0c:87:5f:ef:00:06,netdev=gns3-6 -netdev '
#                   'socket,id=gns3-6,udp=127.0.0.1:10029,localaddr=127.0.0.1:10028 '
#                   '-device e1000,mac=0c:87:5f:ef:00:07,netdev=gns3-7 -netdev '
#                   'socket,id=gns3-7,udp=127.0.0.1:10031,localaddr=127.0.0.1:10030 '
#                   '-device e1000,mac=0c:87:5f:ef:00:08,netdev=gns3-8 -netdev '
#                   'socket,id=gns3-8,udp=127.0.0.1:10033,localaddr=127.0.0.1:10032 '
#                   '-device e1000,mac=0c:87:5f:ef:00:09,netdev=gns3-9 -netdev '
#                   'socket,id=gns3-9,udp=127.0.0.1:10035,localaddr=127.0.0.1:10034 '
#                   '-device e1000,mac=0c:87:5f:ef:00:0a,netdev=gns3-10 -netdev '
#                   'socket,id=gns3-10,udp=127.0.0.1:10037,localaddr=127.0.0.1:10036 '
#                   '-device e1000,mac=0c:87:5f:ef:00:0b,netdev=gns3-11 -netdev '
#                   'socket,id=gns3-11,udp=127.0.0.1:10039,localaddr=127.0.0.1:10038 '
#                   '-device e1000,mac=0c:87:5f:ef:00:0c,netdev=gns3-12 -netdev '
#                   'socket,id=gns3-12,udp=127.0.0.1:10041,localaddr=127.0.0.1:10040 '
#                   '-device e1000,mac=0c:87:5f:ef:00:0d,netdev=gns3-13 -netdev '
#                   'socket,id=gns3-13,udp=127.0.0.1:10043,localaddr=127.0.0.1:10042 '
#                   '-device e1000,mac=0c:87:5f:ef:00:0e,netdev=gns3-14 -netdev '
#                   'socket,id=gns3-14,udp=127.0.0.1:10045,localaddr=127.0.0.1:10044 '
#                   '-device e1000,mac=0c:87:5f:ef:00:0f,netdev=gns3-15 -netdev '
#                   'socket,id=gns3-15,udp=127.0.0.1:10047,localaddr=127.0.0.1:10046 '
#                   '-display none',
#   'compute_id': 'local',
#   'console': 5016,
#   'console_auto_start': False,
#   'console_host': '0.0.0.0',
#   'console_type': 'telnet',
#   'custom_adapters': [],
#   'first_port_name': '',
#   'height': 60,
#   'label': {'rotation': 0,
#             'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                      'bold;fill: #000000;fill-opacity: 1.0;',
#             'text': 'R-3',
#             'x': 15,
#             'y': -25},
#   'locked': False,
#   'name': 'R-3',
#   'node_directory': '/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/5f875fef-f795-4f06-96b2-9c34a66a296d',
#   'node_id': '5f875fef-f795-4f06-96b2-9c34a66a296d',
#   'node_type': 'qemu',
#   'port_name_format': 'Ge 0/{0}',
#   'port_segment_size': 0,
#   'ports': [{'adapter_number': 0,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:00',
#              'name': 'Ge 0/0',
#              'port_number': 0,
#              'short_name': 'Ge 0/0'},
#             {'adapter_number': 1,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:01',
#              'name': 'Ge 0/1',
#              'port_number': 0,
#              'short_name': 'Ge 0/1'},
#             {'adapter_number': 2,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:02',
#              'name': 'Ge 0/2',
#              'port_number': 0,
#              'short_name': 'Ge 0/2'},
#             {'adapter_number': 3,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:03',
#              'name': 'Ge 0/3',
#              'port_number': 0,
#              'short_name': 'Ge 0/3'},
#             {'adapter_number': 4,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:04',
#              'name': 'Ge 0/4',
#              'port_number': 0,
#              'short_name': 'Ge 0/4'},
#             {'adapter_number': 5,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:05',
#              'name': 'Ge 0/5',
#              'port_number': 0,
#              'short_name': 'Ge 0/5'},
#             {'adapter_number': 6,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:06',
#              'name': 'Ge 0/6',
#              'port_number': 0,
#              'short_name': 'Ge 0/6'},
#             {'adapter_number': 7,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:07',
#              'name': 'Ge 0/7',
#              'port_number': 0,
#              'short_name': 'Ge 0/7'},
#             {'adapter_number': 8,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:08',
#              'name': 'Ge 0/8',
#              'port_number': 0,
#              'short_name': 'Ge 0/8'},
#             {'adapter_number': 9,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:09',
#              'name': 'Ge 0/9',
#              'port_number': 0,
#              'short_name': 'Ge 0/9'},
#             {'adapter_number': 10,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:0a',
#              'name': 'Ge 0/10',
#              'port_number': 0,
#              'short_name': 'Ge 0/10'},
#             {'adapter_number': 11,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:0b',
#              'name': 'Ge 0/11',
#              'port_number': 0,
#              'short_name': 'Ge 0/11'},
#             {'adapter_number': 12,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:0c',
#              'name': 'Ge 0/12',
#              'port_number': 0,
#              'short_name': 'Ge 0/12'},
#             {'adapter_number': 13,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:0d',
#              'name': 'Ge 0/13',
#              'port_number': 0,
#              'short_name': 'Ge 0/13'},
#             {'adapter_number': 14,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:0e',
#              'name': 'Ge 0/14',
#              'port_number': 0,
#              'short_name': 'Ge 0/14'},
#             {'adapter_number': 15,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:87:5f:ef:00:0f',
#              'name': 'Ge 0/15',
#              'port_number': 0,
#              'short_name': 'Ge 0/15'}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'properties': {'adapter_type': 'e1000',
#                  'adapters': 16,
#                  'bios_image': '',
#                  'bios_image_md5sum': None,
#                  'boot_priority': 'c',
#                  'cdrom_image': '',
#                  'cdrom_image_md5sum': None,
#                  'cpu_throttling': 0,
#                  'cpus': 1,
#                  'create_config_disk': False,
#                  'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                  'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                  'hda_disk_interface': 'virtio',
#                  'hdb_disk_image': '',
#                  'hdb_disk_image_md5sum': None,
#                  'hdb_disk_interface': 'none',
#                  'hdc_disk_image': '',
#                  'hdc_disk_image_md5sum': None,
#                  'hdc_disk_interface': 'none',
#                  'hdd_disk_image': '',
#                  'hdd_disk_image_md5sum': None,
#                  'hdd_disk_interface': 'none',
#                  'initrd': '',
#                  'initrd_md5sum': None,
#                  'kernel_command_line': '',
#                  'kernel_image': '',
#                  'kernel_image_md5sum': None,
#                  'legacy_networking': False,
#                  'linked_clone': True,
#                  'mac_address': '0c:87:5f:ef:00:00',
#                  'on_close': 'power_off',
#                  'options': '',
#                  'platform': 'x86_64',
#                  'process_priority': 'normal',
#                  'qemu_path': '/usr/bin/qemu-system-x86_64',
#                  'ram': 512,
#                  'replicate_network_connection_state': True,
#                  'tpm': False,
#                  'uefi': False,
#                  'usage': 'Cisco IOSv Virtual Router Platform'},
#   'status': 'started',
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'width': 60,
#   'x': -180,
#   'y': -30,
#   'z': 1},
#  {'command_line': '/usr/bin/qemu-system-x86_64 -name R-4 -m 512M -smp '
#                   'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                   '-drive '
#                   'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                   '-uuid ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7 -serial '
#                   'telnet:127.0.0.1:5003,server,nowait -monitor '
#                   'tcp:127.0.0.1:40405,server,nowait -net none -device '
#                   'e1000,mac=0c:b2:e0:f0:00:00,netdev=gns3-0 -netdev '
#                   'socket,id=gns3-0,udp=127.0.0.1:10113,localaddr=127.0.0.1:10112 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:01,netdev=gns3-1 -netdev '
#                   'socket,id=gns3-1,udp=127.0.0.1:10115,localaddr=127.0.0.1:10114 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:02,netdev=gns3-2 -netdev '
#                   'socket,id=gns3-2,udp=127.0.0.1:10117,localaddr=127.0.0.1:10116 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:03,netdev=gns3-3 -netdev '
#                   'socket,id=gns3-3,udp=127.0.0.1:10119,localaddr=127.0.0.1:10118 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:04,netdev=gns3-4 -netdev '
#                   'socket,id=gns3-4,udp=127.0.0.1:10121,localaddr=127.0.0.1:10120 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:05,netdev=gns3-5 -netdev '
#                   'socket,id=gns3-5,udp=127.0.0.1:10123,localaddr=127.0.0.1:10122 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:06,netdev=gns3-6 -netdev '
#                   'socket,id=gns3-6,udp=127.0.0.1:10125,localaddr=127.0.0.1:10124 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:07,netdev=gns3-7 -netdev '
#                   'socket,id=gns3-7,udp=127.0.0.1:10127,localaddr=127.0.0.1:10126 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:08,netdev=gns3-8 -netdev '
#                   'socket,id=gns3-8,udp=127.0.0.1:10129,localaddr=127.0.0.1:10128 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:09,netdev=gns3-9 -netdev '
#                   'socket,id=gns3-9,udp=127.0.0.1:10131,localaddr=127.0.0.1:10130 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:0a,netdev=gns3-10 -netdev '
#                   'socket,id=gns3-10,udp=127.0.0.1:10133,localaddr=127.0.0.1:10132 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:0b,netdev=gns3-11 -netdev '
#                   'socket,id=gns3-11,udp=127.0.0.1:10135,localaddr=127.0.0.1:10134 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:0c,netdev=gns3-12 -netdev '
#                   'socket,id=gns3-12,udp=127.0.0.1:10137,localaddr=127.0.0.1:10136 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:0d,netdev=gns3-13 -netdev '
#                   'socket,id=gns3-13,udp=127.0.0.1:10139,localaddr=127.0.0.1:10138 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:0e,netdev=gns3-14 -netdev '
#                   'socket,id=gns3-14,udp=127.0.0.1:10141,localaddr=127.0.0.1:10140 '
#                   '-device e1000,mac=0c:b2:e0:f0:00:0f,netdev=gns3-15 -netdev '
#                   'socket,id=gns3-15,udp=127.0.0.1:10143,localaddr=127.0.0.1:10142 '
#                   '-display none',
#   'compute_id': 'local',
#   'console': 5018,
#   'console_auto_start': False,
#   'console_host': '0.0.0.0',
#   'console_type': 'telnet',
#   'custom_adapters': [],
#   'first_port_name': '',
#   'height': 60,
#   'label': {'rotation': 0,
#             'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                      'bold;fill: #000000;fill-opacity: 1.0;',
#             'text': 'R-4',
#             'x': 19,
#             'y': -23},
#   'locked': False,
#   'name': 'R-4',
#   'node_directory': '/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7',
#   'node_id': 'ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7',
#   'node_type': 'qemu',
#   'port_name_format': 'Ge 0/{0}',
#   'port_segment_size': 0,
#   'ports': [{'adapter_number': 0,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:00',
#              'name': 'Ge 0/0',
#              'port_number': 0,
#              'short_name': 'Ge 0/0'},
#             {'adapter_number': 1,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:01',
#              'name': 'Ge 0/1',
#              'port_number': 0,
#              'short_name': 'Ge 0/1'},
#             {'adapter_number': 2,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:02',
#              'name': 'Ge 0/2',
#              'port_number': 0,
#              'short_name': 'Ge 0/2'},
#             {'adapter_number': 3,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:03',
#              'name': 'Ge 0/3',
#              'port_number': 0,
#              'short_name': 'Ge 0/3'},
#             {'adapter_number': 4,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:04',
#              'name': 'Ge 0/4',
#              'port_number': 0,
#              'short_name': 'Ge 0/4'},
#             {'adapter_number': 5,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:05',
#              'name': 'Ge 0/5',
#              'port_number': 0,
#              'short_name': 'Ge 0/5'},
#             {'adapter_number': 6,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:06',
#              'name': 'Ge 0/6',
#              'port_number': 0,
#              'short_name': 'Ge 0/6'},
#             {'adapter_number': 7,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:07',
#              'name': 'Ge 0/7',
#              'port_number': 0,
#              'short_name': 'Ge 0/7'},
#             {'adapter_number': 8,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:08',
#              'name': 'Ge 0/8',
#              'port_number': 0,
#              'short_name': 'Ge 0/8'},
#             {'adapter_number': 9,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:09',
#              'name': 'Ge 0/9',
#              'port_number': 0,
#              'short_name': 'Ge 0/9'},
#             {'adapter_number': 10,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:0a',
#              'name': 'Ge 0/10',
#              'port_number': 0,
#              'short_name': 'Ge 0/10'},
#             {'adapter_number': 11,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:0b',
#              'name': 'Ge 0/11',
#              'port_number': 0,
#              'short_name': 'Ge 0/11'},
#             {'adapter_number': 12,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:0c',
#              'name': 'Ge 0/12',
#              'port_number': 0,
#              'short_name': 'Ge 0/12'},
#             {'adapter_number': 13,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:0d',
#              'name': 'Ge 0/13',
#              'port_number': 0,
#              'short_name': 'Ge 0/13'},
#             {'adapter_number': 14,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:0e',
#              'name': 'Ge 0/14',
#              'port_number': 0,
#              'short_name': 'Ge 0/14'},
#             {'adapter_number': 15,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:b2:e0:f0:00:0f',
#              'name': 'Ge 0/15',
#              'port_number': 0,
#              'short_name': 'Ge 0/15'}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'properties': {'adapter_type': 'e1000',
#                  'adapters': 16,
#                  'bios_image': '',
#                  'bios_image_md5sum': None,
#                  'boot_priority': 'c',
#                  'cdrom_image': '',
#                  'cdrom_image_md5sum': None,
#                  'cpu_throttling': 0,
#                  'cpus': 1,
#                  'create_config_disk': False,
#                  'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                  'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                  'hda_disk_interface': 'virtio',
#                  'hdb_disk_image': '',
#                  'hdb_disk_image_md5sum': None,
#                  'hdb_disk_interface': 'none',
#                  'hdc_disk_image': '',
#                  'hdc_disk_image_md5sum': None,
#                  'hdc_disk_interface': 'none',
#                  'hdd_disk_image': '',
#                  'hdd_disk_image_md5sum': None,
#                  'hdd_disk_interface': 'none',
#                  'initrd': '',
#                  'initrd_md5sum': None,
#                  'kernel_command_line': '',
#                  'kernel_image': '',
#                  'kernel_image_md5sum': None,
#                  'legacy_networking': False,
#                  'linked_clone': True,
#                  'mac_address': '0c:b2:e0:f0:00:00',
#                  'on_close': 'power_off',
#                  'options': '',
#                  'platform': 'x86_64',
#                  'process_priority': 'normal',
#                  'qemu_path': '/usr/bin/qemu-system-x86_64',
#                  'ram': 512,
#                  'replicate_network_connection_state': True,
#                  'tpm': False,
#                  'uefi': False,
#                  'usage': 'Cisco IOSv Virtual Router Platform'},
#   'status': 'started',
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'width': 60,
#   'x': 120,
#   'y': -30,
#   'z': 1},
#  {'command_line': '/usr/bin/qemu-system-x86_64 -name R-5 -m 512M -smp '
#                   'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                   '-drive '
#                   'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/18dd23f5-fd10-49a8-8b1c-a0f741356a12/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                   '-uuid 18dd23f5-fd10-49a8-8b1c-a0f741356a12 -serial '
#                   'telnet:127.0.0.1:5004,server,nowait -monitor '
#                   'tcp:127.0.0.1:35571,server,nowait -net none -device '
#                   'e1000,mac=0c:dd:23:f5:00:00,netdev=gns3-0 -netdev '
#                   'socket,id=gns3-0,udp=127.0.0.1:10145,localaddr=127.0.0.1:10144 '
#                   '-device e1000,mac=0c:dd:23:f5:00:01,netdev=gns3-1 -netdev '
#                   'socket,id=gns3-1,udp=127.0.0.1:10147,localaddr=127.0.0.1:10146 '
#                   '-device e1000,mac=0c:dd:23:f5:00:02,netdev=gns3-2 -netdev '
#                   'socket,id=gns3-2,udp=127.0.0.1:10149,localaddr=127.0.0.1:10148 '
#                   '-device e1000,mac=0c:dd:23:f5:00:03,netdev=gns3-3 -netdev '
#                   'socket,id=gns3-3,udp=127.0.0.1:10151,localaddr=127.0.0.1:10150 '
#                   '-device e1000,mac=0c:dd:23:f5:00:04,netdev=gns3-4 -netdev '
#                   'socket,id=gns3-4,udp=127.0.0.1:10153,localaddr=127.0.0.1:10152 '
#                   '-device e1000,mac=0c:dd:23:f5:00:05,netdev=gns3-5 -netdev '
#                   'socket,id=gns3-5,udp=127.0.0.1:10155,localaddr=127.0.0.1:10154 '
#                   '-device e1000,mac=0c:dd:23:f5:00:06,netdev=gns3-6 -netdev '
#                   'socket,id=gns3-6,udp=127.0.0.1:10157,localaddr=127.0.0.1:10156 '
#                   '-device e1000,mac=0c:dd:23:f5:00:07,netdev=gns3-7 -netdev '
#                   'socket,id=gns3-7,udp=127.0.0.1:10159,localaddr=127.0.0.1:10158 '
#                   '-device e1000,mac=0c:dd:23:f5:00:08,netdev=gns3-8 -netdev '
#                   'socket,id=gns3-8,udp=127.0.0.1:10161,localaddr=127.0.0.1:10160 '
#                   '-device e1000,mac=0c:dd:23:f5:00:09,netdev=gns3-9 -netdev '
#                   'socket,id=gns3-9,udp=127.0.0.1:10163,localaddr=127.0.0.1:10162 '
#                   '-device e1000,mac=0c:dd:23:f5:00:0a,netdev=gns3-10 -netdev '
#                   'socket,id=gns3-10,udp=127.0.0.1:10165,localaddr=127.0.0.1:10164 '
#                   '-device e1000,mac=0c:dd:23:f5:00:0b,netdev=gns3-11 -netdev '
#                   'socket,id=gns3-11,udp=127.0.0.1:10167,localaddr=127.0.0.1:10166 '
#                   '-device e1000,mac=0c:dd:23:f5:00:0c,netdev=gns3-12 -netdev '
#                   'socket,id=gns3-12,udp=127.0.0.1:10169,localaddr=127.0.0.1:10168 '
#                   '-device e1000,mac=0c:dd:23:f5:00:0d,netdev=gns3-13 -netdev '
#                   'socket,id=gns3-13,udp=127.0.0.1:10171,localaddr=127.0.0.1:10170 '
#                   '-device e1000,mac=0c:dd:23:f5:00:0e,netdev=gns3-14 -netdev '
#                   'socket,id=gns3-14,udp=127.0.0.1:10173,localaddr=127.0.0.1:10172 '
#                   '-device e1000,mac=0c:dd:23:f5:00:0f,netdev=gns3-15 -netdev '
#                   'socket,id=gns3-15,udp=127.0.0.1:10175,localaddr=127.0.0.1:10174 '
#                   '-display none',
#   'compute_id': 'local',
#   'console': 5020,
#   'console_auto_start': False,
#   'console_host': '0.0.0.0',
#   'console_type': 'telnet',
#   'custom_adapters': [],
#   'first_port_name': '',
#   'height': 60,
#   'label': {'rotation': 0,
#             'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                      'bold;fill: #000000;fill-opacity: 1.0;',
#             'text': 'R-5',
#             'x': 15,
#             'y': -25},
#   'locked': False,
# ...
#             {'adapter_number': 7,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:07',
#              'name': 'Ge 0/7',
#              'port_number': 0,
#              'short_name': 'Ge 0/7'},
#             {'adapter_number': 8,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:08',
#              'name': 'Ge 0/8',
#              'port_number': 0,
#              'short_name': 'Ge 0/8'},
#             {'adapter_number': 9,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:09',
#              'name': 'Ge 0/9',
#              'port_number': 0,
#              'short_name': 'Ge 0/9'},
#             {'adapter_number': 10,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:0a',
#              'name': 'Ge 0/10',
#              'port_number': 0,
#              'short_name': 'Ge 0/10'},
#             {'adapter_number': 11,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:0b',
#              'name': 'Ge 0/11',
#              'port_number': 0,
#              'short_name': 'Ge 0/11'},
#             {'adapter_number': 12,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:0c',
#              'name': 'Ge 0/12',
#              'port_number': 0,
#              'short_name': 'Ge 0/12'},
#             {'adapter_number': 13,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:0d',
#              'name': 'Ge 0/13',
#              'port_number': 0,
#              'short_name': 'Ge 0/13'},
#             {'adapter_number': 14,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:0e',
#              'name': 'Ge 0/14',
#              'port_number': 0,
#              'short_name': 'Ge 0/14'},
#             {'adapter_number': 15,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:dd:23:f5:00:0f',
#              'name': 'Ge 0/15',
#              'port_number': 0,
#              'short_name': 'Ge 0/15'}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'properties': {'adapter_type': 'e1000',
#                  'adapters': 16,
#                  'bios_image': '',
#                  'bios_image_md5sum': None,
#                  'boot_priority': 'c',
#                  'cdrom_image': '',
#                  'cdrom_image_md5sum': None,
#                  'cpu_throttling': 0,
#                  'cpus': 1,
#                  'create_config_disk': False,
#                  'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                  'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                  'hda_disk_interface': 'virtio',
#                  'hdb_disk_image': '',
#                  'hdb_disk_image_md5sum': None,
#                  'hdb_disk_interface': 'none',
#                  'hdc_disk_image': '',
#                  'hdc_disk_image_md5sum': None,
#                  'hdc_disk_interface': 'none',
#                  'hdd_disk_image': '',
#                  'hdd_disk_image_md5sum': None,
#                  'hdd_disk_interface': 'none',
#                  'initrd': '',
#                  'initrd_md5sum': None,
#                  'kernel_command_line': '',
#                  'kernel_image': '',
#                  'kernel_image_md5sum': None,
#                  'legacy_networking': False,
#                  'linked_clone': True,
#                  'mac_address': '0c:dd:23:f5:00:00',
#                  'on_close': 'power_off',
#                  'options': '',
#                  'platform': 'x86_64',
#                  'process_priority': 'normal',
#                  'qemu_path': '/usr/bin/qemu-system-x86_64',
#                  'ram': 512,
#                  'replicate_network_connection_state': True,
#                  'tpm': False,
#                  'uefi': False,
#                  'usage': 'Cisco IOSv Virtual Router Platform'},
#   'status': 'started',
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'width': 60,
#   'x': -30,
#   'y': 195,
#   'z': 1},
#  {'command_line': '/usr/bin/qemu-system-x86_64 -name R-6 -m 512M -smp '
#                   'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                   '-drive '
#                   'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/320b1ee0-fc0e-47ac-a818-a9280a925bb6/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                   '-uuid 320b1ee0-fc0e-47ac-a818-a9280a925bb6 -serial '
#                   'telnet:127.0.0.1:5005,server,nowait -monitor '
#                   'tcp:127.0.0.1:42857,server,nowait -net none -device '
#                   'e1000,mac=0c:0b:1e:e0:00:00,netdev=gns3-0 -netdev '
#                   'socket,id=gns3-0,udp=127.0.0.1:10177,localaddr=127.0.0.1:10176 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:01,netdev=gns3-1 -netdev '
#                   'socket,id=gns3-1,udp=127.0.0.1:10179,localaddr=127.0.0.1:10178 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:02,netdev=gns3-2 -netdev '
#                   'socket,id=gns3-2,udp=127.0.0.1:10181,localaddr=127.0.0.1:10180 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:03,netdev=gns3-3 -netdev '
#                   'socket,id=gns3-3,udp=127.0.0.1:10183,localaddr=127.0.0.1:10182 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:04,netdev=gns3-4 -netdev '
#                   'socket,id=gns3-4,udp=127.0.0.1:10185,localaddr=127.0.0.1:10184 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:05,netdev=gns3-5 -netdev '
#                   'socket,id=gns3-5,udp=127.0.0.1:10187,localaddr=127.0.0.1:10186 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:06,netdev=gns3-6 -netdev '
#                   'socket,id=gns3-6,udp=127.0.0.1:10189,localaddr=127.0.0.1:10188 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:07,netdev=gns3-7 -netdev '
#                   'socket,id=gns3-7,udp=127.0.0.1:10191,localaddr=127.0.0.1:10190 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:08,netdev=gns3-8 -netdev '
#                   'socket,id=gns3-8,udp=127.0.0.1:10193,localaddr=127.0.0.1:10192 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:09,netdev=gns3-9 -netdev '
#                   'socket,id=gns3-9,udp=127.0.0.1:10195,localaddr=127.0.0.1:10194 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:0a,netdev=gns3-10 -netdev '
#                   'socket,id=gns3-10,udp=127.0.0.1:10197,localaddr=127.0.0.1:10196 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:0b,netdev=gns3-11 -netdev '
#                   'socket,id=gns3-11,udp=127.0.0.1:10199,localaddr=127.0.0.1:10198 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:0c,netdev=gns3-12 -netdev '
#                   'socket,id=gns3-12,udp=127.0.0.1:10201,localaddr=127.0.0.1:10200 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:0d,netdev=gns3-13 -netdev '
#                   'socket,id=gns3-13,udp=127.0.0.1:10203,localaddr=127.0.0.1:10202 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:0e,netdev=gns3-14 -netdev '
#                   'socket,id=gns3-14,udp=127.0.0.1:10205,localaddr=127.0.0.1:10204 '
#                   '-device e1000,mac=0c:0b:1e:e0:00:0f,netdev=gns3-15 -netdev '
#                   'socket,id=gns3-15,udp=127.0.0.1:10207,localaddr=127.0.0.1:10206 '
#                   '-display none',
#   'compute_id': 'local',
#   'console': 5022,
#   'console_auto_start': False,
#   'console_host': '0.0.0.0',
#   'console_type': 'telnet',
#   'custom_adapters': [],
#   'first_port_name': '',
#   'height': 60,
#   'label': {'rotation': 0,
#             'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                      'bold;fill: #000000;fill-opacity: 1.0;',
#             'text': 'R-6',
#             'x': 15,
#             'y': -25},
#   'locked': False,
#   'name': 'R-6',
#   'node_directory': '/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/320b1ee0-fc0e-47ac-a818-a9280a925bb6',
#   'node_id': '320b1ee0-fc0e-47ac-a818-a9280a925bb6',
#   'node_type': 'qemu',
#   'port_name_format': 'Ge 0/{0}',
#   'port_segment_size': 0,
#   'ports': [{'adapter_number': 0,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:00',
#              'name': 'Ge 0/0',
#              'port_number': 0,
#              'short_name': 'Ge 0/0'},
#             {'adapter_number': 1,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:01',
#              'name': 'Ge 0/1',
#              'port_number': 0,
#              'short_name': 'Ge 0/1'},
#             {'adapter_number': 2,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:02',
#              'name': 'Ge 0/2',
#              'port_number': 0,
#              'short_name': 'Ge 0/2'},
#             {'adapter_number': 3,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:03',
#              'name': 'Ge 0/3',
#              'port_number': 0,
#              'short_name': 'Ge 0/3'},
#             {'adapter_number': 4,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:04',
#              'name': 'Ge 0/4',
#              'port_number': 0,
#              'short_name': 'Ge 0/4'},
#             {'adapter_number': 5,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:05',
#              'name': 'Ge 0/5',
#              'port_number': 0,
#              'short_name': 'Ge 0/5'},
#             {'adapter_number': 6,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:06',
#              'name': 'Ge 0/6',
#              'port_number': 0,
#              'short_name': 'Ge 0/6'},
#             {'adapter_number': 7,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:07',
#              'name': 'Ge 0/7',
#              'port_number': 0,
#              'short_name': 'Ge 0/7'},
#             {'adapter_number': 8,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:08',
#              'name': 'Ge 0/8',
#              'port_number': 0,
#              'short_name': 'Ge 0/8'},
#             {'adapter_number': 9,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:09',
#              'name': 'Ge 0/9',
#              'port_number': 0,
#              'short_name': 'Ge 0/9'},
#             {'adapter_number': 10,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:0a',
#              'name': 'Ge 0/10',
#              'port_number': 0,
#              'short_name': 'Ge 0/10'},
#             {'adapter_number': 11,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:0b',
#              'name': 'Ge 0/11',
#              'port_number': 0,
#              'short_name': 'Ge 0/11'},
#             {'adapter_number': 12,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:0c',
#              'name': 'Ge 0/12',
#              'port_number': 0,
#              'short_name': 'Ge 0/12'},
#             {'adapter_number': 13,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:0d',
#              'name': 'Ge 0/13',
#              'port_number': 0,
#              'short_name': 'Ge 0/13'},
#             {'adapter_number': 14,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:0e',
#              'name': 'Ge 0/14',
#              'port_number': 0,
#              'short_name': 'Ge 0/14'},
#             {'adapter_number': 15,
#              'adapter_type': 'e1000',
#              'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#              'link_type': 'ethernet',
#              'mac_address': '0c:0b:1e:e0:00:0f',
#              'name': 'Ge 0/15',
#              'port_number': 0,
#              'short_name': 'Ge 0/15'}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'properties': {'adapter_type': 'e1000',
#                  'adapters': 16,
#                  'bios_image': '',
#                  'bios_image_md5sum': None,
#                  'boot_priority': 'c',
#                  'cdrom_image': '',
#                  'cdrom_image_md5sum': None,
#                  'cpu_throttling': 0,
#                  'cpus': 1,
#                  'create_config_disk': False,
#                  'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                  'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                  'hda_disk_interface': 'virtio',
#                  'hdb_disk_image': '',
#                  'hdb_disk_image_md5sum': None,
#                  'hdb_disk_interface': 'none',
#                  'hdc_disk_image': '',
#                  'hdc_disk_image_md5sum': None,
#                  'hdc_disk_interface': 'none',
#                  'hdd_disk_image': '',
#                  'hdd_disk_image_md5sum': None,
#                  'hdd_disk_interface': 'none',
#                  'initrd': '',
#                  'initrd_md5sum': None,
#                  'kernel_command_line': '',
#                  'kernel_image': '',
#                  'kernel_image_md5sum': None,
#                  'legacy_networking': False,
#                  'linked_clone': True,
#                  'mac_address': '0c:0b:1e:e0:00:00',
#                  'on_close': 'power_off',
#                  'options': '',
#                  'platform': 'x86_64',
#                  'process_priority': 'normal',
#                  'qemu_path': '/usr/bin/qemu-system-x86_64',
#                  'ram': 512,
#                  'replicate_network_connection_state': True,
#                  'tpm': False,
#                  'uefi': False,
#                  'usage': 'Cisco IOSv Virtual Router Platform'},
#   'status': 'started',
#   'symbol': ':/symbols/affinity/square/blue/router.svg',
#   'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#   'width': 60,
#   'x': -30,
#   'y': 345,
#   'z': 1}]

# %%
pprint(conn.get_node(
    node_id='320b1ee0-fc0e-47ac-a818-a9280a925bb6', 
    project_id='f2f7ed27-7aa3-4b11-a64c-da947a2c7210'
    )
    )
# Out:
# {'command_line': '/usr/bin/qemu-system-x86_64 -name R-6 -m 512M -smp '
#                  'cpus=1,sockets=1 -enable-kvm -machine smm=off -boot order=c '
#                  '-drive '
#                  'file=/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/320b1ee0-fc0e-47ac-a818-a9280a925bb6/hda_disk.qcow2,if=virtio,index=0,media=disk,id=drive0 '
#                  '-uuid 320b1ee0-fc0e-47ac-a818-a9280a925bb6 -serial '
#                  'telnet:127.0.0.1:5005,server,nowait -monitor '
#                  'tcp:127.0.0.1:42857,server,nowait -net none -device '
#                  'e1000,mac=0c:0b:1e:e0:00:00,netdev=gns3-0 -netdev '
#                  'socket,id=gns3-0,udp=127.0.0.1:10177,localaddr=127.0.0.1:10176 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:01,netdev=gns3-1 -netdev '
#                  'socket,id=gns3-1,udp=127.0.0.1:10179,localaddr=127.0.0.1:10178 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:02,netdev=gns3-2 -netdev '
#                  'socket,id=gns3-2,udp=127.0.0.1:10181,localaddr=127.0.0.1:10180 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:03,netdev=gns3-3 -netdev '
#                  'socket,id=gns3-3,udp=127.0.0.1:10183,localaddr=127.0.0.1:10182 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:04,netdev=gns3-4 -netdev '
#                  'socket,id=gns3-4,udp=127.0.0.1:10185,localaddr=127.0.0.1:10184 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:05,netdev=gns3-5 -netdev '
#                  'socket,id=gns3-5,udp=127.0.0.1:10187,localaddr=127.0.0.1:10186 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:06,netdev=gns3-6 -netdev '
#                  'socket,id=gns3-6,udp=127.0.0.1:10189,localaddr=127.0.0.1:10188 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:07,netdev=gns3-7 -netdev '
#                  'socket,id=gns3-7,udp=127.0.0.1:10191,localaddr=127.0.0.1:10190 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:08,netdev=gns3-8 -netdev '
#                  'socket,id=gns3-8,udp=127.0.0.1:10193,localaddr=127.0.0.1:10192 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:09,netdev=gns3-9 -netdev '
#                  'socket,id=gns3-9,udp=127.0.0.1:10195,localaddr=127.0.0.1:10194 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:0a,netdev=gns3-10 -netdev '
#                  'socket,id=gns3-10,udp=127.0.0.1:10197,localaddr=127.0.0.1:10196 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:0b,netdev=gns3-11 -netdev '
#                  'socket,id=gns3-11,udp=127.0.0.1:10199,localaddr=127.0.0.1:10198 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:0c,netdev=gns3-12 -netdev '
#                  'socket,id=gns3-12,udp=127.0.0.1:10201,localaddr=127.0.0.1:10200 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:0d,netdev=gns3-13 -netdev '
#                  'socket,id=gns3-13,udp=127.0.0.1:10203,localaddr=127.0.0.1:10202 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:0e,netdev=gns3-14 -netdev '
#                  'socket,id=gns3-14,udp=127.0.0.1:10205,localaddr=127.0.0.1:10204 '
#                  '-device e1000,mac=0c:0b:1e:e0:00:0f,netdev=gns3-15 -netdev '
#                  'socket,id=gns3-15,udp=127.0.0.1:10207,localaddr=127.0.0.1:10206 '
#                  '-display none',
#  'compute_id': 'local',
#  'console': 5022,
#  'console_auto_start': False,
#  'console_host': '0.0.0.0',
#  'console_type': 'telnet',
#  'custom_adapters': [],
#  'first_port_name': '',
#  'height': 60,
#  'label': {'rotation': 0,
#            'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: '
#                     'bold;fill: #000000;fill-opacity: 1.0;',
#            'text': 'R-6',
#            'x': 15,
#            'y': -25},
#  'locked': False,
#  'name': 'R-6',
#  'node_directory': '/home/yueguobin/GNS3/projects/network_ai/project-files/qemu/320b1ee0-fc0e-47ac-a818-a9280a925bb6',
#  'node_id': '320b1ee0-fc0e-47ac-a818-a9280a925bb6',
#  'node_type': 'qemu',
#  'port_name_format': 'Ge 0/{0}',
#  'port_segment_size': 0,
#  'ports': [{'adapter_number': 0,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:00',
#             'name': 'Ge 0/0',
#             'port_number': 0,
#             'short_name': 'Ge 0/0'},
#            {'adapter_number': 1,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:01',
#             'name': 'Ge 0/1',
#             'port_number': 0,
#             'short_name': 'Ge 0/1'},
#            {'adapter_number': 2,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:02',
#             'name': 'Ge 0/2',
#             'port_number': 0,
#             'short_name': 'Ge 0/2'},
#            {'adapter_number': 3,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:03',
#             'name': 'Ge 0/3',
#             'port_number': 0,
#             'short_name': 'Ge 0/3'},
#            {'adapter_number': 4,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:04',
#             'name': 'Ge 0/4',
#             'port_number': 0,
#             'short_name': 'Ge 0/4'},
#            {'adapter_number': 5,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:05',
#             'name': 'Ge 0/5',
#             'port_number': 0,
#             'short_name': 'Ge 0/5'},
#            {'adapter_number': 6,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:06',
#             'name': 'Ge 0/6',
#             'port_number': 0,
#             'short_name': 'Ge 0/6'},
#            {'adapter_number': 7,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:07',
#             'name': 'Ge 0/7',
#             'port_number': 0,
#             'short_name': 'Ge 0/7'},
#            {'adapter_number': 8,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:08',
#             'name': 'Ge 0/8',
#             'port_number': 0,
#             'short_name': 'Ge 0/8'},
#            {'adapter_number': 9,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:09',
#             'name': 'Ge 0/9',
#             'port_number': 0,
#             'short_name': 'Ge 0/9'},
#            {'adapter_number': 10,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:0a',
#             'name': 'Ge 0/10',
#             'port_number': 0,
#             'short_name': 'Ge 0/10'},
#            {'adapter_number': 11,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:0b',
#             'name': 'Ge 0/11',
#             'port_number': 0,
#             'short_name': 'Ge 0/11'},
#            {'adapter_number': 12,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:0c',
#             'name': 'Ge 0/12',
#             'port_number': 0,
#             'short_name': 'Ge 0/12'},
#            {'adapter_number': 13,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:0d',
#             'name': 'Ge 0/13',
#             'port_number': 0,
#             'short_name': 'Ge 0/13'},
#            {'adapter_number': 14,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:0e',
#             'name': 'Ge 0/14',
#             'port_number': 0,
#             'short_name': 'Ge 0/14'},
#            {'adapter_number': 15,
#             'adapter_type': 'e1000',
#             'data_link_types': {'Ethernet': 'DLT_EN10MB'},
#             'link_type': 'ethernet',
#             'mac_address': '0c:0b:1e:e0:00:0f',
#             'name': 'Ge 0/15',
#             'port_number': 0,
#             'short_name': 'Ge 0/15'}],
#  'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#  'properties': {'adapter_type': 'e1000',
#                 'adapters': 16,
#                 'bios_image': '',
#                 'bios_image_md5sum': None,
#                 'boot_priority': 'c',
#                 'cdrom_image': '',
#                 'cdrom_image_md5sum': None,
#                 'cpu_throttling': 0,
#                 'cpus': 1,
#                 'create_config_disk': False,
#                 'hda_disk_image': 'vios-adventerprisek9-m.spa.159-3.m4.qcow2',
#                 'hda_disk_image_md5sum': '355b13ab821e64e2939fd7008d6304d7',
#                 'hda_disk_interface': 'virtio',
#                 'hdb_disk_image': '',
#                 'hdb_disk_image_md5sum': None,
#                 'hdb_disk_interface': 'none',
#                 'hdc_disk_image': '',
#                 'hdc_disk_image_md5sum': None,
#                 'hdc_disk_interface': 'none',
#                 'hdd_disk_image': '',
#                 'hdd_disk_image_md5sum': None,
#                 'hdd_disk_interface': 'none',
#                 'initrd': '',
#                 'initrd_md5sum': None,
#                 'kernel_command_line': '',
#                 'kernel_image': '',
#                 'kernel_image_md5sum': None,
#                 'legacy_networking': False,
#                 'linked_clone': True,
#                 'mac_address': '0c:0b:1e:e0:00:00',
#                 'on_close': 'power_off',
#                 'options': '',
#                 'platform': 'x86_64',
#                 'process_priority': 'normal',
#                 'qemu_path': '/usr/bin/qemu-system-x86_64',
#                 'ram': 512,
#                 'replicate_network_connection_state': True,
#                 'tpm': False,
#                 'uefi': False,
#                 'usage': 'Cisco IOSv Virtual Router Platform'},
#  'status': 'started',
#  'symbol': ':/symbols/affinity/square/blue/router.svg',
#  'template_id': 'b923a635-b7cc-4cb5-9a86-9357e04c02f7',
#  'width': 60,
#  'x': -30,
#  'y': 345,
#  'z': 1}

# %%
pprint(conn.get_links(project_id='f2f7ed27-7aa3-4b11-a64c-da947a2c7210'))
# Out:
# [{'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': '5460af38-6056-4188-899c-31abaca8e947',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 3,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/3',
#                        'x': 38,
#                        'y': -33},
#              'node_id': '770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#              'port_number': 0},
#             {'adapter_number': 2,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/2',
#                        'x': 30,
#                        'y': -50},
#              'node_id': '5f875fef-f795-4f06-96b2-9c34a66a296d',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': 'cb99bbdf-742b-4c4e-8a86-824dd8a37ff6',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 4,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/4',
#                        'x': 62,
#                        'y': 56},
#              'node_id': '770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#              'port_number': 0},
#             {'adapter_number': 2,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/2',
#                        'x': -44,
#                        'y': 27},
#              'node_id': 'ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': '4d4f8786-db0e-4f6a-953e-10c2aac05554',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 5,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/5',
#                        'x': 71,
#                        'y': 5},
#              'node_id': '5f875fef-f795-4f06-96b2-9c34a66a296d',
#              'port_number': 0},
#             {'adapter_number': 3,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/3',
#                        'x': -53,
#                        'y': -13},
#              'node_id': '18dd23f5-fd10-49a8-8b1c-a0f741356a12',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': 'e50226ce-5591-4496-afe2-ddcd59482a02',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 5,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/5',
#                        'x': 60,
#                        'y': 27},
#              'node_id': 'ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7',
#              'port_number': 0},
#             {'adapter_number': 4,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/4',
#                        'x': -49,
#                        'y': 50},
#              'node_id': '18dd23f5-fd10-49a8-8b1c-a0f741356a12',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': 'a40cbe75-ad59-403a-b9ab-4b819b03cd3a',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 0,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/0',
#                        'x': 70,
#                        'y': 30},
#              'node_id': '18dd23f5-fd10-49a8-8b1c-a0f741356a12',
#              'port_number': 0},
#             {'adapter_number': 0,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/0',
#                        'x': -55,
#                        'y': 35},
#              'node_id': '320b1ee0-fc0e-47ac-a818-a9280a925bb6',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': '389123f7-6282-4583-ba8f-1a758970323e',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 0,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/0',
#                        'x': 30,
#                        'y': 70},
#              'node_id': '5f875fef-f795-4f06-96b2-9c34a66a296d',
#              'port_number': 0},
#             {'adapter_number': 0,
#              'label': {'rotation': 0,
#                        'style': 'font-family: TypeWriter;font-size: '
#                                 '10.0;font-weight: bold;fill: '
#                                 '#000000;fill-opacity: 1.0;',
#                        'text': 'Ge 0/0',
#                        'x': 30,
#                        'y': -10},
#              'node_id': 'ceb2e0f0-5c7e-48b2-b289-8db2ed92e5a7',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': '6ed6b841-a5ff-419f-ae5c-5a8bbbef9677',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 1,
#              'label': {'text': 'Ge 0/1'},
#              'node_id': 'dae0b5be-03aa-492d-939c-72f2bbe1d74a',
#              'port_number': 0},
#             {'adapter_number': 1,
#              'label': {'text': 'Ge 0/1'},
#              'node_id': '770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False},
#  {'capture_compute_id': None,
#   'capture_file_name': None,
#   'capture_file_path': None,
#   'capturing': False,
#   'filters': {},
#   'link_id': '4bf2afcc-2a26-4f13-8b73-f6c94145d378',
#   'link_style': {},
#   'link_type': 'ethernet',
#   'nodes': [{'adapter_number': 5,
#              'label': {'text': 'Ge 0/5'},
#              'node_id': '770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#              'port_number': 0},
#             {'adapter_number': 1,
#              'label': {'text': 'Ge 0/1'},
#              'node_id': '18dd23f5-fd10-49a8-8b1c-a0f741356a12',
#              'port_number': 0}],
#   'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#   'suspend': False}]

# %%
pprint(
    conn.get_link(
    project_id='f2f7ed27-7aa3-4b11-a64c-da947a2c7210', 
    link_id='5460af38-6056-4188-899c-31abaca8e947'
    )
    )
# Out:
# {'capture_compute_id': None,
#  'capture_file_name': None,
#  'capture_file_path': None,
#  'capturing': False,
#  'filters': {},
#  'link_id': '5460af38-6056-4188-899c-31abaca8e947',
#  'link_style': {},
#  'link_type': 'ethernet',
#  'nodes': [{'adapter_number': 3,
#             'label': {'rotation': 0,
#                       'style': 'font-family: TypeWriter;font-size: '
#                                '10.0;font-weight: bold;fill: '
#                                '#000000;fill-opacity: 1.0;',
#                       'text': 'Ge 0/3',
#                       'x': 38,
#                       'y': -33},
#             'node_id': '770c835c-83ae-42ce-a2b9-9a88fb4d2145',
#             'port_number': 0},
#            {'adapter_number': 2,
#             'label': {'rotation': 0,
#                       'style': 'font-family: TypeWriter;font-size: '
#                                '10.0;font-weight: bold;fill: '
#                                '#000000;fill-opacity: 1.0;',
#                       'text': 'Ge 0/2',
#                       'x': 30,
#                       'y': -50},
#             'node_id': '5f875fef-f795-4f06-96b2-9c34a66a296d',
#             'port_number': 0}],
#  'project_id': 'f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#  'suspend': False}

# %%
pprint(conn.create_project(name="YYYYYYY"))
# Out:
# {'auto_close': True,
#  'auto_open': False,
#  'auto_start': False,
#  'drawing_grid_size': 25,
#  'filename': 'YYYYYYY.gns3',
#  'grid_size': 75,
#  'name': 'YYYYYYY',
#  'path': '/home/yueguobin/GNS3/projects/2f4db42a-361a-4d7e-b1f3-948e27b02467',
#  'project_id': '2f4db42a-361a-4d7e-b1f3-948e27b02467',
#  'scene_height': 1000,
#  'scene_width': 2000,
#  'show_grid': False,
#  'show_interface_labels': False,
#  'show_layers': False,
#  'snap_to_grid': False,
#  'status': 'opened',
#  'supplier': None,
#  'variables': None,
#  'zoom': 100}

# %%
pprint(conn.delete_project(project_id="2f4db42a-361a-4d7e-b1f3-948e27b02467"))
# Out:
# None

# %%
debian_node = Node(
    name="debianrrrrrrr",
    node_type="qemu",
    template="debian13",
    project_id="f2f7ed27-7aa3-4b11-a64c-da947a2c7210",
    connector = conn
)
pprint(debian_node)
pprint(debian_node.create())
# Out:
# Node(name='debianrrrrrrr',
#      project_id='f2f7ed27-7aa3-4b11-a64c-da947a2c7210',
#      node_id=None,
#      compute_id='local',
#      node_type='qemu',
#      node_directory=None,
#      status=None,
#      ports=None,
#      port_name_format=None,
#      port_segment_size=None,
#      first_port_name=None,
#      locked=None,
#      label=None,
#      console=None,
#      console_host=None,
#      console_type=None,
#      console_auto_start=None,
#      command_line=None,
#      custom_adapters=None,
#      height=None,
#      width=None,
#      symbol=None,
#      x=None,
#      y=None,
#      z=None,
#      template_id=None,
#      properties=None,
#      template='debian13')
# None

# %%
node = Node(project_id="f2f7ed27-7aa3-4b11-a64c-da947a2c7210",
             node_id="320b1ee0-fc0e-47ac-a818-a9280a925bb6",
             connector=conn
             )
pprint(node.get())
pprint(node.node_id)
pprint(node.name)
pprint(node.status)
pprint(node.start())
pprint(node.stop())
pprint(node.reload())
# Out:
# None
# '320b1ee0-fc0e-47ac-a818-a9280a925bb6'
# 'R-6'
# 'started'
# True
# True
# True
